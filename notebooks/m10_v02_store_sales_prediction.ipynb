# %% [markdown]
# # 0.0. IMPORTS

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd
import inflection
import math
import numpy as np
import seaborn as sns
import datetime
import matplotlib.gridspec as gridspec
import xgboost as xgb
import random
import warnings
import pickle

from boruta import BorutaPy
from matplotlib import pyplot as plt
from IPython.core.display import HTML
from IPython.display import Image
from tabulate import tabulate
from scipy import stats as ss

from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %% [markdown]
# ## 0.1. Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline

    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24

    display(HTML('<style>.conteiner{width:100% !important;}</style>'))

    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option('display.expand_frame_repr', False)
    # configura o pandas para quantidade de casas decimeis
    pd.set_option('display.float_format', lambda x: '%.2f' % x)

    sns.set()
jupyter_settings()

def ml_error(model_name, y, yhat):
  mae = mean_absolute_error(y, yhat)
  mape = mean_absolute_percentage_error(y, yhat)
  rmse = np.sqrt(mean_squared_error(y, yhat))

  return pd.DataFrame({'Model Name': model_name,
                       'MAE': mae,
                       'MAPE': mape,
                       'RMSE': rmse}, index=[0])
  
def cross_validation(x_training, kfold, model_name, model, verbose=False):
  mae_list = []
  mape_list = []
  rmse_list = []
  for k in reversed(range(1, kfold+1)):
    if verbose:
      print(f'\nKfold number: {k}.')
    # start and end date for validation
    validation_start_date = x_training['date'].max() - datetime.timedelta( days = k*6*7)
    validation_end_date = x_training['date'].max() - datetime.timedelta( days = (k-1)*6*7)

    # filtering dataset
    training = x_training[x_training['date'] < validation_start_date]
    validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

    # training and validation dataset
    # training
    xtraining = training.drop(columns=['date', 'sales'])
    ytraining = training['sales']

    # validation
    xvalidation = validation.drop(columns=['date', 'sales'])
    yvalidation = validation['sales']

    # model
    m = model.fit(xtraining, ytraining)

    # prediction
    yhat = m.predict( xvalidation )

    # performace
    m_result = ml_error(model_name, np.expm1(yvalidation), np.expm1(yhat))
    
    # store performace of each kfold iteration
    mae_list.append(m_result['MAE'])
    mape_list.append(m_result['MAPE'])
    rmse_list.append(m_result['RMSE'])

  return pd.DataFrame({'Model Name': model_name,
                        'MAE CV': np.round(np.mean(mae_list), 2).astype(str) + " +/- " + np.round(np.std(mae_list), 2).astype(str),
                       'MAPE CV': np.round(np.mean(mape_list), 2).astype(str) + " +/- " + np.round(np.std(mape_list), 2).astype(str),
                       'RMSE CV': np.round(np.mean(rmse_list), 2).astype(str) + " +/- " + np.round(np.std(rmse_list), 2).astype(str)}, index=[0])
# Out:
# <style>.conteiner{width:100% !important;}</style>

# %%
def cramer_v(x,y):
    cm = pd.crosstab( x, y ).values
    
    n = cm.sum()
    r, k = cm.shape
    chi2 = ss.chi2_contingency( cm )[0]
    
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )
    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)
    
    return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )

# %% [markdown]
# ## 0.2. Loading data

# %%
jupyter_settings()
# Out:
# <style>.conteiner{width:100% !important;}</style>

# %%
df_sales_raw = pd.read_csv('../data/train.csv', low_memory=False)
df_store_raw = pd.read_csv('../data/store.csv', low_memory=False)

# merge
df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store' )

# %% [markdown]
# # 1.0. DATA DESCRIPTION

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
           'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
           'CompetitionDistance', 'CompetitionOpenSinceMonth',
           'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
           'Promo2SinceYear', 'PromoInterval']

snake_case = lambda x: inflection.underscore( x )

cols_new = list(map(snake_case, cols_old))

# rename
df1.columns = cols_new

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print( 'Number of Rows: {}'.format(df1.shape[0]))
print( 'Number of Columns: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Number of Columns: 18

# %% [markdown]
# ## 1.3. Data Types

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 2.5. Fillout NA

# %%
df1['competition_distance'].max()
# Out:
# 75860.0

# %%
#competition_distance
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)
#competition_open_since_month 
df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month 
                                                if math.isnan(x['competition_open_since_month']) 
                                                else x['competition_open_since_month'], axis=1)
#competition_open_since_year 
df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year
                                                if math.isnan(x['competition_open_since_year']) 
                                                else x['competition_open_since_year'], axis=1)
#promo2_since_week
df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week
                                                if math.isnan(x['promo2_since_week']) 
                                                else x['promo2_since_week'], axis=1)
#promo2_since_year
df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year
                                                if math.isnan(x['promo2_since_year']) 
                                                else x['promo2_since_year'], axis=1)
#promo_interval

month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

df1['promo_interval'].fillna(0, inplace=True)
  
df1['month_map'] = df1['date'].dt.month.map(month_map)

df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split(',') else 0, axis=1)

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %% [markdown]
# ## 1.6. Change Types

# %%
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(int)

df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(int)

df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)

df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)

# %% [markdown]
# ## 1.7. Descriptive Statistical

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'] )
cat_attributes =df1.select_dtypes(exclude=  ['int64', 'float64', 'datetime64[ns]'])

# %%
# Central tendency: mean, median

# Dispersion: std, min, max range, skew, kurtosis

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
# Central tendency: mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion: std, min, max range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply( np.std )).T
d2 = pd.DataFrame(num_attributes.apply( min )).T
d3 = pd.DataFrame(num_attributes.apply( max )).T
d4 = pd.DataFrame(num_attributes.apply( lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply( lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply( lambda x: x.kurtosis())).T


# concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = [ 'attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

# %%
m
# Out:
#                       attributes     min       max     range    mean  median      std  skew  kurtosis
# 0                          store    1.00   1115.00   1114.00  558.43  558.00   321.91 -0.00     -1.20
# 1                    day_of_week    1.00      7.00      6.00    4.00    4.00     2.00  0.00     -1.25
# 2                          sales    0.00  41551.00  41551.00 5773.82 5744.00  3849.92  0.64      1.78
# 3                      customers    0.00   7388.00   7388.00  633.15  609.00   464.41  1.60      7.09
# 4                           open    0.00      1.00      1.00    0.83    1.00     0.38 -1.76      1.09
# 5                          promo    0.00      1.00      1.00    0.38    0.00     0.49  0.49     -1.76
# 6                 school_holiday    0.00      1.00      1.00    0.18    0.00     0.38  1.68      0.82
# 7           competition_distance   20.00 200000.00 199980.00 5935.44 2330.00 12547.65 10.24    147.79
# 8   competition_open_since_month    1.00     12.00     11.00    6.79    7.00     3.31 -0.04     -1.23
# 9    competition_open_since_year 1900.00   2015.00    115.00 2010.32 2012.00     5.52 -7.24    124.07
# 10                        promo2    0.00      1.00      1.00    0.50    1.00     0.50 -0.00     -2.00
# 11             promo2_since_week    1.00     52.00     51.00   23.62   22.00    14.31  0.18     -1.18
# 12             promo2_since_year 2009.00   2015.00      6.00 2012.79 2013.00     1.66 -0.78     -0.21
# 13                      is_promo    0.00      1.00      1.00    0.17    0.00     0.38  1.74      1.03

# %%
sns.distplot(df1['customers'])
# Out:
# /home/naomi/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='customers', ylabel='Density'>

# %% [markdown]
# ### 1.7.2 - Categorical Attributes

# %%
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]


plt.subplot(1,3,1)
sns.boxplot(x='state_holiday', y='sales', data=aux1)

plt.subplot(1,3,2)
sns.boxplot(x='store_type', y='sales', data=aux1)

plt.subplot(1,3,3)
sns.boxplot(x='assortment', y='sales', data=aux1)
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0. FEATURE ENGENEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1. Mindmap Hypothesis

# %%
Image( "../img/MindMapHypothesis.png")

# %% [markdown]
# ## 2.2. Criação de Hipoteses

# %% [markdown]
# ### 2.2.1. Hipóteses Loja

# %% [markdown]
# **1.** Lojas com número maior de funcionários deveriam vender mais.
#
# **2.** Lojas com maior capacidade de estoque deveriam vender mais.
#
# **3.** Lojas com maior porte deveriam vender mais.
#
# **4.** Lojas com maior sortimentos deveriam vender mais.
#
# **5.** Lojas com competidores mais próximos deveriam vender menos.
#
# **6.** Lojas com competidores à mais tempo deveriam vendem mais.

# %% [markdown]
# ### 2.2.2. Hipóteses Produto

# %% [markdown]
# **1.** Lojas que investem mais em Marketing deveriam vender mais.
#
# **2.** Lojas com maior exposição de produto deveriam vender mais.
#
# **3.** Lojas com produtos com preço menor deveriam vender mais.
#
# **5.** Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais.
#
# **6.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **7.** Lojas com mais dias de promoção deveriam vender mais.
#
# **8.** Lojas com mais promoções consecutivas deveriam vender mais.

# %% [markdown]
# ###  2.2.3. Hipóteses Tempo

# %% [markdown]
# **1.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **2.** Lojas deveriam vender mais ao longo dos anos.
#
# **3.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **4.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **5.** Lojas deveriam vender menos aos finais de semana.
#
# **6.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ### 2.2.4 Lista Final de Hipóteses

# %% [markdown]
# **1.** Lojas com maior sortimentos deveriam vender mais.
#
# **2.** Lojas com competidores mais próximos deveriam vender menos.
#
# **3.** Lojas com competidores à mais tempo deveriam vendem mais.
#
# **4.** Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **5.** Lojas com mais dias de promoção deveriam vender mais.
#
# **6.** Lojas com mais promoções consecutivas deveriam vender mais.
#
# **7.** Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **8.** Lojas deveriam vender mais ao longo dos anos.
#
# **9.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **10.** Lojas deveriam vender mais depois do dia 10 de cada mês.
#
# **11.** Lojas deveriam vender menos aos finais de semana.
#
# **12.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.3. Feature Engeeniring

# %%
df2 = df1.copy()

# year
df2['year'] = df2['date'].dt.year

# month
df2['month'] = df2['date'].dt.month

# day
df2['day'] = df2['date'].dt.day

# week of year
df2['week_of_year'] = df2['date'].dt.weekofyear

# year week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

# competition since
df2['competition_since'] = df2.apply(lambda x: datetime.datetime(year=x['competition_open_since_year'], 
                                                                 month = x['competition_open_since_month'], 
                                                                 day=1), axis=1)
df2['competition_time_month'] = ((df2['date'] - df2['competition_since'])/30).apply(lambda x: x.days).astype(int)


# promo since
df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype(str)

df2['promo_since'] = df2['promo_since'].apply(lambda x: datetime.datetime.strptime( x + '-1', "%Y-%W-%w" ) - 
                                              datetime.timedelta( days=7 ))

df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply(lambda x: x.days ).astype( int )

# assortment
df2['assortment'] = df2['assortment'].apply(lambda x: 'basic' if x== 'a' else 'extra' if x == 'b' else 'extended')


# state holiday
df2['state_holiday'] = df2['state_holiday'].apply(lambda x: 'public_holiday' if x == 'a'
                           else 'easter_holiday' if x == 'b' 
                           else 'christmas' if x == 'c' 
                           else 'regular_day')
# Out:
# /tmp/ipykernel_23395/3116045501.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2['week_of_year'] = df2['date'].dt.weekofyear

# %% [markdown]
# # 3.0. - FILTRAGEM DE VARIÁVEIS

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1. Filtragem das Linhas

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2. Filtragem das Colunas

# %%
# customers: dado indisponível no momento da previsão

df3 = df3.drop(columns=['customers', 'open', 'promo_interval', 'month_map'], axis=1)

# %% [markdown]
# # 4.0. - ANÁLISE EXPLORATÓRIA DOS DADOS

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1. Análise Univariada

# %% [markdown]
# ### 4.1.1. Response Variable

# %%
sns.histplot(np.log1p(df4['sales']))
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Count'>

# %% [markdown]
# ### 4.1.2. Numerical Variable

# %%
num_attributes.hist(bins=25);

# %% [markdown]
# ### 4.1.3. Categorical Variable

# %%
cat_attributes.head()
# Out:
#   state_holiday store_type assortment   promo_interval month_map
# 0             0          c          a                0       Jul
# 1             0          a          a  Jan,Apr,Jul,Oct       Jul
# 2             0          a          a  Jan,Apr,Jul,Oct       Jul
# 3             0          c          c                0       Jul
# 4             0          a          a                0       Jul

# %%
df4['assortment'].unique()
# Out:
# array(['basic', 'extended', 'extra'], dtype=object)

# %%
# state holiday
a = df4[df4['state_holiday'] != 'regular_day']
plt.subplot(3, 2, 1)
sns.countplot(a['state_holiday']);
plt.subplot(3, 2, 2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday', shade=True )
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday', shade=True )
sns.kdeplot(df4[df4['state_holiday'] == 'christmas']['sales'], label='christmas', shade=True )
plt.legend()

# store_type
plt.subplot(3, 2, 3)
sns.countplot(df3['store_type']);
plt.subplot(3, 2, 4)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label='a', shade=True )
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label='b', shade=True )
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label='c', shade=True )
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label='d', shade=True )
plt.legend()

# assortment
plt.subplot(3, 2, 5)
sns.countplot(df3['assortment']);
plt.subplot(3, 2, 6)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label='basic', shade=True )
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label='extra', shade=True )
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label='extended', shade=True )
plt.legend()
# Out:
# /home/naomi/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/naomi/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/naomi/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 4.2. Análise Bivariada

# %% [markdown]
# #### H1. Lojas com maior sortimentos deveriam vender mais.
# **R:**
#
# Volume absoluto: **falso**
#
# Volume médio por loja: **verdadeiro**
#
# O volume de vendas por loja por dia é maior nas lojas do tipo 'extra', porém o número de lojas com esse tipo de sortimento é menor.

# %%
aux1 = df4[['assortment', 'sales']].groupby('assortment').median().reset_index()
sns.barplot(y='sales', x='assortment', data=aux1);

aux2 = df4[['year_week', 'assortment', 'sales']].groupby( ['year_week','assortment'] ).median().reset_index()
aux2.pivot( index='year_week', columns='assortment', values='sales' ).plot()
# Out:
# <AxesSubplot:xlabel='year_week'>

# %% [markdown]
# ####  H2. Lojas com competidores mais próximos deveriam vender menos.
# **R: Falso**. Lojas com competidores mais próximos vendem mais.

# %%
aux1 = df4[['competition_distance', 'sales']].groupby( 'competition_distance' ).sum().reset_index()

plt.subplot( 1, 3, 1 )
sns.scatterplot( x ='competition_distance', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
bins = list( np.arange( 0, 20000, 1000) )
aux1['competition_distance_binned'] = pd.cut( aux1['competition_distance'], bins=bins )

aux2 = aux1[['competition_distance_binned', 'sales']].groupby('competition_distance_binned' ).sum().reset_index()
sns.barplot( x='competition_distance_binned', y='sales', data=aux2 );
plt.xticks( rotation=90 );
plt.subplot( 1, 3, 3 )
x = sns.heatmap( aux1.corr( method='pearson' ), annot=True );
bottom, top = x.get_ylim()
x.set_ylim( bottom+0.5, top-0.5 );

# %% [markdown]
# #### H3. Lojas com competidores à mais tempo deveriam vendem mais.
#
# **R: Falso**. Lojas com concorrencia aberta a mais tempo vendem menos.

# %%
plt.subplot( 1, 3, 1 )
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month' ).mean().reset_index()
aux2 = aux1[( aux1['competition_time_month'] < 120 ) & (aux1['competition_time_month'] != 0 )]
sns.barplot( x='competition_time_month', y='sales', data=aux2 );
plt.xticks( rotation=90 );
plt.subplot( 1, 3, 2 )
sns.regplot( x='competition_time_month', y='sales', data=aux2 );
plt.subplot( 1, 3, 3 )
x = sns.heatmap( aux1.corr( method='pearson'), annot=True );
bottom, top = x.get_ylim()
x.set_ylim( bottom+0.5, top-0.5);

# %% [markdown]
# #### H4. Lojas com promoções ativas por mais tempo deveriam vender mais.
#
# **R: Falso.** Lojas em promoção por mais tempo não vendem mais.

# %%
aux1 = df4[['promo_time_week', 'sales']].groupby( 'promo_time_week').mean().reset_index()

grid = gridspec.GridSpec( 2, 3 )

plt.subplot( grid[0,0] )
aux2 = aux1[aux1['promo_time_week'] > 0] # promo extendido
sns.barplot( x='promo_time_week', y='sales', data=aux2 );
plt.xticks( rotation=90 );

plt.subplot( grid[0,1] )
sns.regplot( x='promo_time_week', y='sales', data=aux2 );

plt.subplot( grid[1,0] )
aux3 = aux1[aux1['promo_time_week'] < 0] # promo regular
sns.barplot( x='promo_time_week', y='sales', data=aux3 );
plt.xticks( rotation=90 );

plt.subplot( grid[1,1] )
sns.regplot( x='promo_time_week', y='sales', data=aux3 );

plt.subplot( grid[:,2] )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# #### H5. Lojas com mais dias de promoção deveriam vender mais.
# Resposta no próximo ciclo

# %% [markdown]
# #### H6. Lojas com mais promoções consecutivas deveriam vender mais.
# **R: Falso.** Lojas com promoçoes consecutivas vendem menos

# %%
df4[['promo', 'promo2', 'sales']].groupby( ['promo', 'promo2'] ).mean().reset_index()
# Out:
#    promo  promo2   sales
# 0      0       0 6328.19
# 1      0       1 5529.57
# 2      1       0 8618.45
# 3      1       1 7836.67

# %%
aux1 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 1 )][['year_week', 'sales']].groupby( 'year_week' ).mean().reset_index()
ax = aux1.plot()
aux2 = df4[( df4['promo'] == 1 ) & ( df4['promo2'] == 0 )][['year_week', 'sales']].groupby( 'year_week' ).mean().reset_index()
aux2.plot( ax=ax )
ax.legend( labels=['Tradicional & Extendida', 'Extendida']);

# %% [markdown]
# #### H7. Lojas abertas durante o feriado de Natal deveriam vender mais.
#
# **R: Verdadeiro.** Lojas abertas durante o feriado de natal vendem mais.

# %%
plt.subplot(1, 2, 1)
aux1 = df4[['state_holiday', 'sales']].groupby('state_holiday').mean().reset_index()
sns.barplot(x='state_holiday', y='sales', data=aux1);

plt.subplot(1, 2, 2)
aux2 = df4[['year', 'state_holiday', 'sales']].groupby(['state_holiday', 'year',]).mean().reset_index()
sns.barplot(x='year', y='sales', hue='state_holiday', data=aux2);

# %% [markdown]
# #### **H8.** Lojas deveriam vender mais ao longo dos anos.
# **R: Verdadeiro.** As vendas médias por loja aumentaram ao longo dos anos.

# %%
aux1 = df4[['sales', 'year']].groupby('year').mean().reset_index()
plt.subplot(1, 3, 1)
sns.barplot(x='year', y='sales', data=aux1);

plt.subplot(1, 3, 2)
sns.regplot(x='year', y='sales', data=aux1);

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# #### **H9.** Lojas deveriam vender mais no segundo semestre do ano.
# **R: Falso.** A média de vendas do primeiro semestre é maior, mas a diferença é pouco significativa.

# %%
aux1 = df4[['sales', 'month']].groupby('month').mean().reset_index()
plt.subplot(1, 3, 1)
sns.barplot(x='month', y='sales', data=aux1);

plt.subplot(1, 3, 2)
sns.regplot(x='month', y='sales', data=aux1);

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

print(aux1['sales'][0:5].mean())
print(aux1['sales'][6:11].mean())
# Out:
# 6856.815591549322
# 6788.359097928716

# %% [markdown]
# #### **H10.** Lojas deveriam vender mais depois do dia 10 de cada mês.
# **R: Falso.** O volume médio por dia de vendas após o dia 10 é menor.

# %%
aux1 = df4[['day', 'sales']].groupby( 'day' ).sum().reset_index()

plt.subplot( 2, 2, 1 )
sns.barplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 2 )
sns.regplot( x='day', y='sales', data=aux1 );

plt.subplot( 2, 2, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

aux1['before_after'] = aux1['day'].apply( lambda x: 'before_10_days' if x <= 10 else 'after_10_days' )
aux2 = aux1[['before_after', 'sales']].groupby( 'before_after' ).mean().reset_index()

plt.subplot( 2, 2, 4 )
sns.barplot( x='before_after', y='sales', data=aux2 );

# %% [markdown]
# #### **H11.** Lojas deveriam vender menos aos finais de semana.
# **R: Falso.** Lojas abertas aos finais de semana vendem mais aos domingos e segundas-feiras.

# %%
aux1 = df4[['day_of_week', 'sales']].groupby( 'day_of_week' ).mean().reset_index()

plt.subplot( 1, 3, 1 )
sns.barplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 2 )
sns.regplot( x='day_of_week', y='sales', data=aux1 );

plt.subplot( 1, 3, 3 )
sns.heatmap( aux1.corr( method='pearson' ), annot=True );

# %% [markdown]
# #### **H12.** Lojas deveriam vender menos durante os feriados escolares.
#
# **R: Verdadeiro.** As vendas durante os feriados escolares são sensivelmente maiores.

# %%
aux1 = df4[['school_holiday', 'sales']].groupby('school_holiday').mean().reset_index()

plt.subplot( 2, 1, 1 )
sns.barplot( x='school_holiday', y='sales', data=aux1 );

aux2 = df4[['month', 'school_holiday', 'sales']].groupby(['month','school_holiday'] ).mean().reset_index()
plt.subplot( 2, 1, 2 )
sns.barplot( x='month', y='sales', hue='school_holiday', data=aux2 );

# %% [markdown]
# ### 4.2.1 Resumo das Hipóteses

# %%
tab =[['Hipoteses', 'Conclusao', 'Relevancia'],
['H1', 'Verdadeira', 'Baixa'],
['H2', 'Falsa', 'Media'],
['H3', 'Falsa', 'Media'],
['H4', 'Falsa', 'Baixa'],
['H5', '-', '-'],
['H6', 'Falsa', 'Baixa'],
['H7', 'Verdadeira', 'Media'],
['H8', 'Verdadeira', 'Alta'],
['H9', 'Falsa', 'Alta'],
['H10', 'Falsa', 'Alta'],
['H11', 'Verdadeira', 'Alta'],
['H12', 'Verdadeira', 'Baixa'],
]
print( tabulate( tab, headers='firstrow' ) )
# Out:
# Hipoteses    Conclusao    Relevancia
# -----------  -----------  ------------
# H1           Verdadeira   Baixa
# H2           Falsa        Media
# H3           Falsa        Media
# H4           Falsa        Baixa
# H5           -            -
# H6           Falsa        Baixa
# H7           Verdadeira   Media
# H8           Verdadeira   Alta
# H9           Falsa        Alta
# H10          Falsa        Alta
# H11          Verdadeira   Alta
# H12          Verdadeira   Baixa

# %% [markdown]
# ## 4.3. Analise Multivariada

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
correlation = num_attributes.corr(method='pearson')
sns.heatmap( correlation, annot=True)
# Out:
# <AxesSubplot:>

# %%
num_attributes.columns
# Out:
# Index(['store', 'day_of_week', 'sales', 'customers', 'open', 'promo',
#        'school_holiday', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo'],
#       dtype='object')

# %% [markdown]
# ### 4.3.1 Categorical Attributes

# %%
# only categorical data
a = df4.select_dtypes(include='object')

# calculate cramer v:
a1 = cramer_v(a['state_holiday'], a['state_holiday'])
a2 = cramer_v(a['state_holiday'], a['store_type'])
a3 = cramer_v(a['state_holiday'], a['assortment'])

a4 = cramer_v(a['store_type'], a['state_holiday'])
a5 = cramer_v(a['store_type'], a['store_type'])
a6 = cramer_v(a['store_type'], a['assortment'])

a7 = cramer_v(a['assortment'], a['state_holiday'])
a8 = cramer_v(a['assortment'], a['store_type'])
a9 = cramer_v(a['assortment'], a['assortment'])


# Final dataset:
d = pd.DataFrame({'state_holiday': [a1, a2, a3],
              'store_type': [a4, a5, a6],
              'assortment': [a7, a8, a9]
             })
d = d.set_index(d.columns)

sns.heatmap( d, annot=True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0. - PASSO 05 - DATA PREPARATION

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1. Normalização

# %%
# none

# %% [markdown]
# ## 5.2. Rescaling

# %%
rs = RobustScaler()
mms = MinMaxScaler()

# competition distance - robust scaler
df5['competition_distance'] = rs.fit_transform(df5[['competition_distance']].values)
pickle.dump(rs, open('../parameter/competition_distance_scaler.pkl', 'wb'))

# competition time month
df5['competition_time_month'] = rs.fit_transform(df5[['competition_time_month']].values)
pickle.dump(rs, open('../parameter/competition_time_month_scaler.pkl', 'wb'))


# promo time week
df5['promo_time_week'] = mms.fit_transform(df5[['promo_time_week']].values)
pickle.dump(mms, open('../parameter/promo_time_week_scaler.pkl', 'wb'))

# year
df5['year'] = mms.fit_transform(df5[['year']].values)
pickle.dump(mms, open('../parameter/year_scaler.pkl', 'wb'))

# %% [markdown]
# ## 5.3. Transformação

# %% [markdown]
# ### 5.3.1. Encoding

# %%
# state_holiday - One hot encoding
df5 = pd.get_dummies(df5, prefix = ['state_holiday'], columns=['state_holiday'])


#store_type - Label Encoding
le = LabelEncoder()
df5['store_type'] = le.fit_transform(df5['store_type'])
pickle.dump(le, open('../parameter/store_type_encoding.pkl', 'wb'))

# assortment - Ordinal Encoding
assortment_dict = {'basic':1, 'extra':2, 'extended':3 }

df5['assortment'] = df5['assortment'].map(assortment_dict)

# %% [markdown]
# ### 5.3.2. Response Variable Transformation

# %%
df5['sales'] = np.log1p( df5['sales'] )

# %% [markdown]
# ### 5.3.3. Nature Transformation

# %%
# day of week
df5['day_of_week_sin']= df5['day_of_week'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 7)))
df5['day_of_week_cos']= df5['day_of_week'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 7)))

# month
df5['month_sin']= df5['month'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 12)))
df5['month_cos']= df5['month'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 12)))

# day
df5['day_sin']= df5['day'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 31)))
df5['day_cos']= df5['day'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 31)))


# week of year
df5['week_of_year_sin']= df5['week_of_year'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 52)))
df5['week_of_year_cos']= df5['week_of_year'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 52)))

# %% [markdown]
# # 6.0. PASSO 06 - FEATURE SELECTION

# %%
df6 = df5.copy()

# %% [markdown]
# ##  6.1. Split dataframe into training and test dataset

# %%
cols_drop = ['week_of_year', 'day', 'month', 'day_of_week', 'promo_since','competition_since', 'year_week' ]
df6 = df6.drop( cols_drop, axis=1 )

# %%
# training dataset
X_train = df6[df6['date'] < '2015-06-19']
Y_train = X_train['sales']
# test dataset
X_test = df6[df6['date'] >= '2015-06-19']
Y_test = X_test['sales']
print( 'Training Min Date: {}'.format( X_train['date'].min() ) )
print( 'Training Max Date: {}'.format( X_train['date'].max() ) )
print( '\nTest Min Date: {}'.format( X_test['date'].min() ) )
print( 'Test Max Date: {}'.format( X_test['date'].max() ) )
# Out:
# Training Min Date: 2013-01-01 00:00:00
# Training Max Date: 2015-06-18 00:00:00
#
# Test Min Date: 2015-06-19 00:00:00
# Test Max Date: 2015-07-31 00:00:00

# %% [markdown]
#  ## 6.2. Boruta as Feature Selector

# %%
## training and test dataset for Boruta
#X_train_n = X_train.drop( ['date', 'sales'], axis=1 ).values
#y_train_n = y_train.values.ravel()

# define RandomForestRegressor
#rf = RandomForestRegressor( n_jobs=-1 )

# define Boruta
#boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=42 ).fit(X_train_n, y_train_n )

# %%
#cols_selected = boruta.support_.tolist()

# best features from boruta
#X_train_fs = X_train.drop(['date', 'sales'], axis=1)
#cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns

# not selected from boruta
#cols_not_selected_boruta = list(np.setdiff1d(X_train_fs.columns, cols_selected_boruta))

# %%
#cols_selected_boruta

# Index(['store', 'promo', 'store_type', 'assortment', 'competition_distance',
#       'competition_open_since_month', 'competition_open_since_year', 'promo2',
#       'promo2_since_week', 'promo2_since_year', 'competition_time_month',
#       'promo_time_week', 'day_of_week_sin', 'day_of_week_cos', 'montht_cos',
#       'day_sin', 'day_cos', 'week_of_year_cos'],
#      dtype='object')

# %% [markdown]
# ## 6.3. Manual Feature selection

# %%
cols_selected_boruta = ['store', 
                        'promo', 
                        'store_type', 
                        'assortment', 
                        'competition_distance',
                        'competition_open_since_month', 
                        'competition_open_since_year', 
                        'promo2',
                        'promo2_since_week', 
                        'promo2_since_year', 
                        'competition_time_month',
                        'promo_time_week', 
                        'day_of_week_sin', 
                        'day_of_week_cos', 
                        'month_sin',
                        'month_cos', 
                        'day_sin', 
                        'day_cos', 
                        'week_of_year_sin',
                        'week_of_year_cos']

# columns to add
feat_to_add = ['date', 'sales']

# final features
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend(feat_to_add)

# %% [markdown]
# ## 7.0. PASSO 07 - MACHINE LEARNING MODELLING

# %%
x_train = X_train[cols_selected_boruta]

x_test = X_test[cols_selected_boruta]

x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1. Average Model

# %%
aux1 = x_test.copy()
aux1['sales'] = Y_test.copy()

# prediction
aux2 = aux1[['store', 'sales']].groupby('store').mean().reset_index().rename(columns={'sales': 'predictions'})
aux1 = pd.merge( aux1, aux2, how='left', on='store')
yhat_baseline = aux1['predictions']

# performace
baseline_result = ml_error('Avarage Model', np.expm1(Y_test), np.expm1(yhat_baseline))
baseline_result
# Out:
#       Model Name     MAE  MAPE    RMSE
# 0  Avarage Model 1354.80  0.21 1835.14

# %% [markdown]
# ## 7.2. Linear Regression Model

# %%
#x_train_lr = x_train.copy()
#x_train_lr.dtypes

#x_test_lr = x_test.drop(columns=['date'])
#x_test_lr.dtypes

# %%
# model
lr = LinearRegression().fit( x_train, Y_train )
# prediction
yhat_lr = lr.predict( x_test )

# performance
lr_result = ml_error( 'Linear Regression', np.expm1(Y_test), np.expm1(yhat_lr) )
lr_result
# Out:
#           Model Name     MAE  MAPE    RMSE
# 0  Linear Regression 1867.65  0.29 2671.33

# %% [markdown]
# ### 7.2.1. Linear Regression Model - Cross Validation

# %%
model=LinearRegression()
lr_result_cv = cross_validation(x_training, 5, "Linear Regression", lr)

# %%
lr_result_cv
# Out:
#           Model Name              MAE CV       MAPE CV             RMSE CV
# 0  Linear Regression  2081.31 +/- 295.69  0.3 +/- 0.02  2951.88 +/- 468.22

# %% [markdown]
# ## 7.3. Linear Regression Regularizaded Model - Lasso - Cross Validation

# %%
# model
lrr = Lasso(alpha=0.01).fit( x_train, Y_train )

# prediction
yhat_lrr = lr.predict( x_test )

# performance
lrr_result = ml_error( 'Linear Regression Lasso', np.expm1(Y_test), np.expm1(yhat_lrr) )
lrr_result
# Out:
#                 Model Name     MAE  MAPE    RMSE
# 0  Linear Regression Lasso 1867.65  0.29 2683.34

# %% [markdown]
# ### 7.3.1. Linear Regression Regularizaded Model - Lasso

# %%
lrr_result_cv = cross_validation(x_training, 5, "Linear Regression Lasso", lrr)

# %%
lrr_result_cv
# Out:
#                 Model Name              MAE CV        MAPE CV             RMSE CV
# 0  Linear Regression Lasso  2115.78 +/- 341.38  0.29 +/- 0.01  3056.85 +/- 503.74

# %% [markdown]
# ## 7.4. Random Forest Regressor

# %%
## model
#rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42).fit( x_train, Y_train )

## prediction
#yhat_rf = rf.predict( x_test )

## performance
#rf_result = ml_error( 'Random Forest Regressor', np.expm1(Y_test), np.expm1(yhat_rf) )

# %%
#rf_result.to_csv('/content/drive/MyDrive/Data Scientist/ds-em-producao/data/rf_result.csv')

# %% [markdown]
# ### 7.4.1. Random Forest Regressor - Cross Validation

# %%
#rf_result_cv = cross_validation(x_training, 5, "Random Forest Regressor", rf, verbose=True)

# %%
#rf_result_cv

# %% [markdown]
# ## 7.5. XGBoost Regressor

# %%
# model
#model_xgb = xgb.XGBRegressor(objectve='reg:squarederror',
#                             n_estimators=100,
#                             eta=0.01,
#                             max_depth=10,
#                             subsample=0.7,
#                             colsample_bytree=0.9
#                             ).fit( x_train, Y_train )

# prediction
#yhat_xgb = model_xgb.predict( x_test )

# performance
#xgb_result = ml_error( 'XG Boost Regressor', np.expm1(Y_test), np.expm1(yhat_xgb) )
#xgb_result

# %% [markdown]
# ### 7.5.1. XGBoost Regressor - Cross Validation

# %%
#xgb_result_cv = cross_validation(x_training, 5, "XGBoost Regressor", model_xgb, verbose=True)

# %%
#xgb_result_cv

# %% [markdown]
# ## 7.6. Compare Model's Performace

# %% [markdown]
# ### 7.6.1. Single Performace

# %%
#modelling_result = pd.concat([baseline_result, lr_result, lrr_result, rf_result, xgb_result]).reset_index(drop=True)
#modelling_result.to_csv('/content/drive/MyDrive/Data Scientist/ds-em-producao/data/modelling_result.csv')

# %%
#modelling_result

# %% [markdown]
# ### 7.6.2. Real Performance - Cross Validation

# %%
# modelling_result_cv = pd.concat( [lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv] )
# modelling_result_cv.to_csv('/content/drive/MyDrive/Data Scientist/ds-em-producao/data/modelling_result_cv.csv')
#modelling_result_cv

# %% [markdown]
# # 8.0. PASSO 8 - Hyperparameter Fine Tuning

# %% [markdown]
# ## 8.1. Random Search

# %%
warnings.filterwarnings('ignore')

# %%
param = {'n_estimators':[1500, 1700, 2500, 3000, 3500],
         'eta':[0.01, 0.03],
         'max_depth': [3, 5, 9],
         'subsample': [0.1, 0.5, 0.7],
         'colsample_bytree': [0.3, 0.7, 0.9],
         'min_child_weight': [3, 8, 15]}

MAX_EVAL=5

# %%
#final_result = pd.DataFrame()

#for i in range(MAX_EVAL):


#  # Choose values for parameters randomly
#  hp = { k: random.sample(v, 1)[0] for k, v in param.items() }
#  print("\n")
#  print(hp)


#  # model
#  model_xgb = xgb.XGBRegressor(objectve='reg:squarederror',
#                              n_estimators=hp['n_estimators'],
#                              eta=hp['eta'],
#                              max_depth=hp['max_depth'],
#                              subsample=hp['subsample'],
#                              colsample_bytree=hp['colsample_bytree'],
#                              min_child_weight=hp['min_child_weight'])




#  # prediction
#  result = cross_validation(x_training, 3, "XGBoost Regressor", model_xgb, verbose=True)
#  final_result = pd.concat([final_result, result])

# %%
#final_result

# %% [markdown]
# ## 8.2. Final Model

# %%
param_tuned = {'n_estimators':3000,
                'eta': 0.03,
                'max_depth': 5,
                'subsample': 0.7,
                'colsample_bytree': 0.7,
                'min_child_weight': 3}

# %%
# model
#model_xgb_tuned = xgb.XGBRegressor(objectve='reg:squarederror',
#                                   n_estimators=param_tuned['n_estimators'],
#                                   eta=param_tuned['eta'],
#                                   max_depth=param_tuned['max_depth'],
#                                   subsample=param_tuned['subsample'],
#                                   colsample_bytree=param_tuned['colsample_bytree'],
#                                   min_child_weight=param_tuned['min_child_weight']).fit(x_train, Y_train)

model_xgb_tuned = model = pickle.load(open('../model/model_rossmann.pkl', 'rb'))
# prediction
yhat_xgb_tuned = model_xgb_tuned.predict(x_test)

# cross validation
xgb_result_tuned = ml_error( 'XG Boost Regressor', np.expm1(Y_test), np.expm1(yhat_xgb_tuned) )
# Out:
# [14:22:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgb_result_tuned
# Out:
#            Model Name    MAE  MAPE   RMSE
# 0  XG Boost Regressor 654.07  0.10 940.52

# %%
mpe = mean_absolute_percentage_error(np.expm1(Y_test), np.expm1(yhat_xgb_tuned))

# %% [markdown]
# # 9.0. PASSO 09 - TRADUÇÃO E INTERPRETAÇÃO DO ERRO

# %%
df9 = X_test[cols_selected_boruta_full]

# rescale
df9['sales'] = np.expm1(df9['sales'])
df9['predictions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ## 9.1. Business Performace

# %%
# sales predicted per store
df91 = df9[['store', 'predictions']].groupby('store').sum().reset_index()
# number of predictions per store
df92 = df9[['store', 'predictions']].groupby('store').count().reset_index()

# MAE and MAPE
df9_aux1 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply(lambda x: mean_absolute_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAE'})
df9_aux2 = df9[['store', 'sales', 'predictions']].groupby( 'store' ).apply(lambda x: mean_absolute_percentage_error( x['sales'], x['predictions'] ) ).reset_index().rename( columns={0:'MAPE'})

# Merge
df9_aux3 = pd.merge( df9_aux1, df9_aux2, how='inner', on='store' )
df92 = pd.merge( df91, df9_aux3, how='inner', on='store' )

# Scenarios
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

# order columns
df92 = df92[['store', 'predictions', 'worst_scenario', 'best_scenario', 'MAE', 'MAPE']]

# %%
df92.sort_values('MAPE', ascending=False).head(10)
# Out:
#       store  predictions  worst_scenario  best_scenario     MAE  MAPE
# 291     292    106031.11       102791.82      109270.40 3239.29  0.55
# 908     909    240734.12       233057.57      248410.68 7676.55  0.53
# 875     876    200621.23       196698.26      204544.21 3922.97  0.30
# 721     722    348135.12       346274.61      349995.64 1860.52  0.25
# 781     782    223216.47       222394.18      224038.76  822.29  0.24
# 273     274    195151.62       193778.41      196524.84 1373.22  0.24
# 594     595    401439.41       397986.07      404892.75 3453.34  0.24
# 1013   1014    422594.84       421044.18      424145.51 1550.66  0.21
# 533     534    284221.47       282898.40      285544.53 1323.06  0.21
# 529     530    239447.64       238017.16      240878.12 1430.48  0.19

# %%
sns.scatterplot( x='store', y='MAPE', data=df92 )
# Out:
# <AxesSubplot:xlabel='store', ylabel='MAPE'>

# %% [markdown]
# ## 9.2. Total Performace

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply( lambda x: np.sum( x ), axis=0 ).reset_index().rename( columns={'index': 'Scenario', 0: 'Values'} )
df93['Values'] = df93['Values'].map( 'R${:,.2f}'.format )
df93
# Out:
#          Scenario            Values
# 0     predictions  R$287,686,784.00
# 1  worst_scenario  R$286,953,671.70
# 2   best_scenario  R$288,419,908.97

# %% [markdown]
# ## 9.3. Machine Learning Performace

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot( 2, 2, 1 )
sns.lineplot( x='date', y='sales', data=df9, label='SALES' )
sns.lineplot( x='date', y='predictions', data=df9, label='PREDICTIONS' )

plt.subplot( 2, 2, 2 )
sns.lineplot( x='date', y='error_rate', data=df9 )
plt.axhline( 1, linestyle='--')

plt.subplot( 2, 2, 3 )
sns.distplot( df9['error'] 
             )
plt.subplot( 2, 2, 4 )
sns.scatterplot( df9['predictions'], df9['error'] )
# Out:
# <AxesSubplot:xlabel='predictions', ylabel='error'>

# %% [markdown]
# # 10.0. PASSO 10 - DEPLOY MODEL TO PRODUCTION

# %%
# Save treined model
#pickle.dump(model_xgb_tuned, open('../model/model_rossmann.pkl', 'wb'))

# %% [markdown]
# ## 10.1. Rossmann Class

# %%
import pickle
import inflection
import pandas as pd
import numpy as np
import math
import datetime

class Rossmann( object ):
    def __init__( self ):
        self.competition_distance_scaler   = pickle.load(open('/home/naomi/repos/ds-em-producao/parameter/competition_distance_scaler.pkl', 'rb'))
        self.competition_time_month_scaler = pickle.load(open('/home/naomi/repos/ds-em-producao/parameter/competition_time_month_scaler.pkl', 'rb'))
        self.promo_time_week_scaler        = pickle.load(open('/home/naomi/repos/ds-em-producao/parameter/promo_time_week_scaler.pkl', 'rb'))
        self.year_scaler                   = pickle.load(open('/home/naomi/repos/ds-em-producao/parameter/year_scaler.pkl', 'rb'))
        self.store_type_encoding           = pickle.load(open('/home/naomi/repos/ds-em-producao/parameter/store_type_encoding.pkl', 'rb'))

    
    def data_cleaning( self, df1 ):

        # 1.1. Rename Columns

        cols_old = ['Store', 'DayOfWeek', 'Date', 'Open', 'Promo',
                    'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
                    'CompetitionDistance', 'CompetitionOpenSinceMonth',
                    'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
                    'Promo2SinceYear', 'PromoInterval']

        snake_case = lambda x: inflection.underscore( x )

        cols_new = list(map(snake_case, cols_old))

        # rename
        df1.columns = cols_new

        df1['date'] = pd.to_datetime( df1['date'])

        ## 1.5. Fillout NA
        #competition_distance
        df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)
        #competition_open_since_month 
        df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month 
                                                        if math.isnan(x['competition_open_since_month']) 
                                                        else x['competition_open_since_month'], axis=1)
        #competition_open_since_year 
        df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year
                                                        if math.isnan(x['competition_open_since_year']) 
                                                        else x['competition_open_since_year'], axis=1)
        #promo2_since_week
        df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week
                                                        if math.isnan(x['promo2_since_week']) 
                                                        else x['promo2_since_week'], axis=1)
        #promo2_since_year
        df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year
                                                        if math.isnan(x['promo2_since_year']) 
                                                        else x['promo2_since_year'], axis=1)
        #promo_interval

        month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

        df1['promo_interval'].fillna(0, inplace=True)

        df1['month_map'] = df1['date'].dt.month.map(month_map)

        df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split(',') else 0, axis=1)

        # Change dtypes
        df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(int)

        df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(int)

        df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)

        df1['promo2_sin ce_year'] = df1['promo2_since_year'].astype(int)

        return df1

    def feature_engineering(self, df2):

        # year
        df2['year'] = df2['date'].dt.year

        # month
        df2['month'] = df2['date'].dt.month

        # day
        df2['day'] = df2['date'].dt.day

        # week of year
        df2['week_of_year'] = df2['date'].dt.weekofyear

        # year week
        df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

        # competition since
        df2['competition_since'] = df2.apply(lambda x: datetime.datetime(year=x['competition_open_since_year'], 
                                                                        month = x['competition_open_since_month'], 
                                                                        day=1), axis=1)
        df2['competition_time_month'] = ((df2['date'] - df2['competition_since'])/30).apply(lambda x: x.days).astype(int)


        # promo since
        df2['promo_since'] = df2['promo2_since_year'].astype(str) + '-' + df2['promo2_since_week'].astype(str)

        df2['promo_since'] = df2['promo_since'].apply(lambda x: datetime.datetime.strptime( x + '-1', "%Y-%W-%w" ) - 
                                                      datetime.timedelta( days=7 ))

        df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply(lambda x: x.days ).astype( int )

        # assortment
        df2['assortment'] = df2['assortment'].apply(lambda x: 'basic' if x== 'a' else 'extra' if x == 'b' else 'extended')


        # state holiday
        df2['state_holiday'] = df2['state_holiday'].apply(lambda x: 'public_holiday' if x == 'a'
                                  else 'easter_holiday' if x == 'b' 
                                  else 'christmas' if x == 'c' 
                                  else 'regular_day')

        # 3.0. - FILTRAGEM DE VARIÁVEIS
        ## 3.1. Filtragem das Linhas
        df2 = df2[(df2['open'] != 0)]
        ## 3.2. Filtragem das Colunas
        # customers: dado indisponível no momento da previsão
        df2 = df2.drop(columns=['open', 'promo_interval', 'month_map'], axis=1)

        return df2

    def data_preparation( self, df5, ft ):
        ## 5.2. Rescaling

        # competition distance - robust scaler
        df5['competition_distance'] = self.competition_distance_scaler.transform( df5[['competition_distance']].values) 

        # competition time month - robust scaler
        df5['competition_time_month'] = self.competition_time_month_scaler.transform( df5[['competition_time_month']].values)

        # promo time week - mms
        df5['promo_time_week'] =self.promo_time_week_scaler.transform(df5[['promo_time_week']].values)

        # year - mms
        df5['year'] = self.year_scaler.transform(df5[['year']].values)

        ### 5.3.1. Encoding
        # state_holiday - One hot encoding
        df5 = pd.get_dummies(df5, prefix = ['state_holiday'], columns=['state_holiday'])


        #store_type - Label Encoding
        df5['store_type'] = self.store_type_encoding.transform(df5['store_type'])

        # assortment - Ordinal Encoding
        assortment_dict = {'basic':1, 'extra':2, 'extended':3 }
        df5['assortment'] = df5['assortment'].map(assortment_dict)


        ### 5.3.3. Nature Transformation
        # day of week
        df5['day_of_week_sin']= df5['day_of_week'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 7)))
        df5['day_of_week_cos']= df5['day_of_week'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 7)))

        # month
        df5['month_sin']= df5['month'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 12)))
        df5['month_cos']= df5['month'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 12)))

        # day
        df5['day_sin']= df5['day'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 31)))
        df5['day_cos']= df5['day'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 31)))


        # week of year
        df5['week_of_year_sin']= df5['week_of_year'].apply(lambda x: np.sin( x * ((2 * np.pi)/ 52)))
        df5['week_of_year_cos']= df5['week_of_year'].apply(lambda x: np.cos( x * ((2 * np.pi)/ 52)))




        cols_selected = ['store', 'promo', 'store_type', 'assortment', 'competition_distance', 'competition_open_since_month', 'competition_open_since_year', 
                                'promo2', 'promo2_since_week', 'promo2_since_year', 'competition_time_month','promo_time_week', 'day_of_week_sin', 'day_of_week_cos', 
                                'month_sin','month_cos', 'day_sin', 'day_cos', 'week_of_year_sin', 'week_of_year_cos']

        return df5[cols_selected]
    
    def get_prediction(self, model, original_data, test_data):
        # prediction
        pred = model.predict(test_data)
    
        # join pred to original data
        original_data['prediction'] = np.expm1(pred)

        return original_data.to_json(orient='records', date_format = 'iso')

# %% [markdown]
# ## 10.2. API Handler

# %%
import pickle
import pandas as pd

from flask             import Flask, request, Response
from rossmann.Rossmann import Rossmann

# loading model
model = pickle.load(open('/home/naomi/repos/ds-em-producao/model/model_rossmann.pkl', 'rb'))

# initialize API
app = Flask(__name__)

@app.route('/rossmann/predict', methods=['POST'])
def rossmann_predict():
    test_json = request.get_json()

    if test_json: # there is data
        if isinstance(test_json, dict): # Unique Exemple
            test_raw = pd.DataFrame(test_json, index=[0])

        else: # Multiple Exemples
            test_raw = pd.DataFrame(test_json, columns=test_jason[0].keys())

     
        # Instanciate Rossmann class
        pipeline = Rossmann()

        # data cleaning
        df1 = pipeline.data_cleaning(test_raw)

        # feature engineering
        df2 = pipeline.feature_engineering(df1)

        # data preparation
        df3 = pipeline.data_preparation(df2)

        # prediction
        df_response = pipeline.get_prediction(model, test_raw, df3)

        return df_response

    else: # no data
        return Response('{}', status=200, mimetype='application/json')

if __name__ == '__main__':
    app.run('0.0.0.0')
# Out:
# [14:23:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.0.11:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ## 10.3. API Tester

# %%
# loading test dataset
df10 = pd.read_csv('/home/naomi/repos/ds-em-producao/data/test.csv')
df10.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17  1.00      1            0              0
# 1   2      3          4  2015-09-17  1.00      1            0              0
# 2   3      7          4  2015-09-17  1.00      1            0              0
# 3   4      8          4  2015-09-17  1.00      1            0              0
# 4   5      9          4  2015-09-17  1.00      1            0              0

# %%
# merge test dataset + store
df_test = pd.merge(df10, df_store_raw, how='left', on='Store')
df_test.head()

# choose store for prediction
#df_test = df_test[df_test['Store'] == 23]

# remove closed days
df_test = df_test[df_test['Open'] != 0]
df_test = df_test[~df_test['Open'].isnull()]
df_test = df_test.drop('Id', axis=1)
df_test.shape
# Out:
# (35093, 16)

# %%
import json
import requests

# %%
# convert DataFrame to JSON
data = json.dumps(df_test.to_dict(orient='records'))

# %%
# API Call
#url = 'http://0.0.0.0:5000/rossmann/predict'
url = 'http://rossmann-model-nkb.herokuapp.com/rossmann/predict'
header = {'Content-type': 'application/json' }
data = data

r = requests.post( url, data=data, headers=header )
print( 'Status Code {}'.format( r.status_code ) )
# Out:
# Status Code 200

# %%
d1 = pd.DataFrame(r.json(), columns=r.json()[0].keys())

# %%
d2 = d1[['store', 'prediction']].groupby( 'store' ).sum().reset_index()
for i in range( len( d2 ) ):
    print( 'Store Number {} will sell R${:,.2f} in the next 6 weeks'.format(
    d2.loc[i, 'store'],
    d2.loc[i, 'prediction'] ) )
# Out:
# Store Number 1 will sell R$174,496.04 in the next 6 weeks
# Store Number 3 will sell R$241,522.76 in the next 6 weeks
# Store Number 7 will sell R$292,483.83 in the next 6 weeks
# Store Number 8 will sell R$239,034.20 in the next 6 weeks
# Store Number 9 will sell R$259,005.27 in the next 6 weeks
# Store Number 10 will sell R$192,957.74 in the next 6 weeks
# Store Number 11 will sell R$283,752.86 in the next 6 weeks
# Store Number 12 will sell R$275,743.84 in the next 6 weeks
# Store Number 13 will sell R$336,271.40 in the next 6 weeks
# Store Number 14 will sell R$227,250.40 in the next 6 weeks
# Store Number 15 will sell R$270,057.32 in the next 6 weeks
# Store Number 16 will sell R$314,023.10 in the next 6 weeks
# Store Number 19 will sell R$264,667.36 in the next 6 weeks
# Store Number 20 will sell R$295,263.68 in the next 6 weeks
# Store Number 21 will sell R$201,691.54 in the next 6 weeks
# Store Number 22 will sell R$195,167.12 in the next 6 weeks
# Store Number 23 will sell R$210,420.47 in the next 6 weeks
# Store Number 24 will sell R$359,673.43 in the next 6 weeks
# Store Number 25 will sell R$415,632.35 in the next 6 weeks
# Store Number 27 will sell R$271,077.35 in the next 6 weeks
# Store Number 29 will sell R$303,240.03 in the next 6 weeks
# Store Number 30 will sell R$179,282.87 in the next 6 weeks
# Store Number 31 will sell R$216,228.52 in the next 6 weeks
# Store Number 32 will sell R$190,237.75 in the next 6 weeks
# Store Number 33 will sell R$273,177.74 in the next 6 weeks
# Store Number 35 will sell R$367,503.15 in the next 6 weeks
# Store Number 36 will sell R$417,233.33 in the next 6 weeks
# Store Number 38 will sell R$188,732.39 in the next 6 weeks
# Store Number 39 will sell R$146,420.73 in the next 6 weeks
# Store Number 40 will sell R$294,955.91 in the next 6 weeks
# Store Number 41 will sell R$223,449.19 in the next 6 weeks
# Store Number 42 will sell R$365,614.82 in the next 6 weeks
# Store Number 43 will sell R$276,241.60 in the next 6 weeks
# Store Number 45 will sell R$184,216.32 in the next 6 weeks
# Store Number 46 will sell R$180,631.92 in the next 6 weeks
# Store Number 47 will sell R$226,678.08 in the next 6 weeks
# Store Number 48 will sell R$204,492.28 in the next 6 weeks
# Store Number 49 will sell R$239,312.58 in the next 6 weeks
# Store Number 50 will sell R$154,721.03 in the next 6 weeks
# Store Number 51 will sell R$262,700.23 in the next 6 weeks
# Store Number 52 will sell R$295,687.18 in the next 6 weeks
# Store Number 53 will sell R$175,450.71 in the next 6 weeks
# Store Number 56 will sell R$248,986.15 in the next 6 weeks
# Store Number 58 will sell R$235,966.16 in the next 6 weeks
# Store Number 61 will sell R$232,299.13 in the next 6 weeks
# Store Number 62 will sell R$255,809.12 in the next 6 weeks
# Store Number 63 will sell R$267,995.16 in the next 6 weeks
# Store Number 64 will sell R$335,785.07 in the next 6 weeks
# Store Number 66 will sell R$224,389.93 in the next 6 weeks
# Store Number 67 will sell R$374,423.48 in the next 6 weeks
# Store Number 68 will sell R$259,444.99 in the next 6 weeks
# Store Number 69 will sell R$284,063.04 in the next 6 weeks
# Store Number 70 will sell R$265,329.30 in the next 6 weeks
# Store Number 71 will sell R$375,276.06 in the next 6 weeks
# Store Number 72 will sell R$196,152.47 in the next 6 weeks
# Store Number 73 will sell R$171,953.13 in the next 6 weeks
# Store Number 74 will sell R$177,470.15 in the next 6 weeks
# Store Number 75 will sell R$337,148.00 in the next 6 weeks
# Store Number 76 will sell R$373,454.99 in the next 6 weeks
# Store Number 77 will sell R$251,670.88 in the next 6 weeks
# Store Number 79 will sell R$192,037.02 in the next 6 weeks
# Store Number 80 will sell R$222,126.68 in the next 6 weeks
# Store Number 81 will sell R$273,548.32 in the next 6 weeks
# Store Number 82 will sell R$406,588.34 in the next 6 weeks
# Store Number 83 will sell R$192,701.81 in the next 6 weeks
# Store Number 84 will sell R$348,583.79 in the next 6 weeks
# Store Number 86 will sell R$257,416.33 in the next 6 weeks
# Store Number 89 will sell R$234,494.20 in the next 6 weeks
# Store Number 90 will sell R$265,602.44 in the next 6 weeks
# Store Number 91 will sell R$205,705.73 in the next 6 weeks
# Store Number 92 will sell R$362,128.68 in the next 6 weeks
# Store Number 93 will sell R$184,869.35 in the next 6 weeks
# Store Number 94 will sell R$303,906.07 in the next 6 weeks
# Store Number 98 will sell R$243,456.66 in the next 6 weeks
# Store Number 99 will sell R$215,960.47 in the next 6 weeks
# Store Number 100 will sell R$218,444.22 in the next 6 weeks
# Store Number 101 will sell R$260,926.02 in the next 6 weeks
# Store Number 102 will sell R$221,404.45 in the next 6 weeks
# Store Number 105 will sell R$187,145.03 in the next 6 weeks
# Store Number 107 will sell R$226,232.08 in the next 6 weeks
# Store Number 108 will sell R$365,289.76 in the next 6 weeks
# Store Number 109 will sell R$243,678.84 in the next 6 weeks
# Store Number 110 will sell R$157,385.57 in the next 6 weeks
# Store Number 111 will sell R$256,634.58 in the next 6 weeks
# Store Number 112 will sell R$279,435.85 in the next 6 weeks
# Store Number 113 will sell R$236,599.21 in the next 6 weeks
# Store Number 115 will sell R$278,244.71 in the next 6 weeks
# Store Number 117 will sell R$178,248.67 in the next 6 weeks
# Store Number 118 will sell R$313,799.35 in the next 6 weeks
# Store Number 119 will sell R$243,039.81 in the next 6 weeks
# Store Number 120 will sell R$282,459.47 in the next 6 weeks
# Store Number 122 will sell R$275,200.29 in the next 6 weeks
# Store Number 124 will sell R$230,578.66 in the next 6 weeks
# Store Number 126 will sell R$231,484.79 in the next 6 weeks
# Store Number 127 will sell R$262,415.75 in the next 6 weeks
# Store Number 128 will sell R$244,422.43 in the next 6 weeks
# Store Number 129 will sell R$231,267.38 in the next 6 weeks
# Store Number 130 will sell R$254,020.64 in the next 6 weeks
# Store Number 131 will sell R$271,347.46 in the next 6 weeks
# Store Number 132 will sell R$235,613.93 in the next 6 weeks
# Store Number 135 will sell R$239,508.00 in the next 6 weeks
# Store Number 136 will sell R$260,263.66 in the next 6 weeks
# Store Number 137 will sell R$268,374.81 in the next 6 weeks
# Store Number 139 will sell R$221,327.52 in the next 6 weeks
# Store Number 140 will sell R$277,258.76 in the next 6 weeks
# Store Number 141 will sell R$238,507.24 in the next 6 weeks
# Store Number 142 will sell R$150,554.87 in the next 6 weeks
# Store Number 143 will sell R$223,594.15 in the next 6 weeks
# Store Number 144 will sell R$231,639.07 in the next 6 weeks
# Store Number 145 will sell R$392,609.17 in the next 6 weeks
# Store Number 146 will sell R$306,194.45 in the next 6 weeks
# Store Number 147 will sell R$295,413.97 in the next 6 weeks
# Store Number 149 will sell R$220,431.88 in the next 6 weeks
# Store Number 150 will sell R$184,838.53 in the next 6 weeks
# Store Number 152 will sell R$253,725.04 in the next 6 weeks
# Store Number 153 will sell R$258,703.23 in the next 6 weeks
# Store Number 154 will sell R$249,428.60 in the next 6 weeks
# Store Number 155 will sell R$251,993.79 in the next 6 weeks
# Store Number 157 will sell R$308,266.07 in the next 6 weeks
# Store Number 158 will sell R$316,779.10 in the next 6 weeks
# Store Number 159 will sell R$278,867.97 in the next 6 weeks
# Store Number 160 will sell R$233,789.05 in the next 6 weeks
# Store Number 161 will sell R$226,933.21 in the next 6 weeks
# Store Number 162 will sell R$308,887.37 in the next 6 weeks
# Store Number 164 will sell R$168,068.04 in the next 6 weeks
# Store Number 165 will sell R$158,985.91 in the next 6 weeks
# Store Number 166 will sell R$232,581.29 in the next 6 weeks
# Store Number 168 will sell R$208,535.20 in the next 6 weeks
# Store Number 169 will sell R$301,269.55 in the next 6 weeks
# Store Number 170 will sell R$193,807.08 in the next 6 weeks
# Store Number 171 will sell R$316,530.81 in the next 6 weeks
# Store Number 172 will sell R$274,792.19 in the next 6 weeks
# Store Number 174 will sell R$168,466.51 in the next 6 weeks
# Store Number 175 will sell R$235,177.70 in the next 6 weeks
# Store Number 176 will sell R$220,952.34 in the next 6 weeks
# Store Number 179 will sell R$419,237.23 in the next 6 weeks
# Store Number 180 will sell R$230,811.10 in the next 6 weeks
# Store Number 181 will sell R$225,352.54 in the next 6 weeks
# Store Number 182 will sell R$268,186.48 in the next 6 weeks
# Store Number 183 will sell R$199,307.89 in the next 6 weeks
# Store Number 184 will sell R$247,563.69 in the next 6 weeks
# Store Number 186 will sell R$154,171.44 in the next 6 weeks
# Store Number 187 will sell R$328,234.49 in the next 6 weeks
# Store Number 188 will sell R$195,576.52 in the next 6 weeks
# Store Number 189 will sell R$259,547.18 in the next 6 weeks
# Store Number 190 will sell R$229,052.58 in the next 6 weeks
# Store Number 191 will sell R$205,402.34 in the next 6 weeks
# Store Number 192 will sell R$280,722.31 in the next 6 weeks
# Store Number 193 will sell R$217,545.16 in the next 6 weeks
# Store Number 194 will sell R$187,071.00 in the next 6 weeks
# Store Number 195 will sell R$245,318.96 in the next 6 weeks
# Store Number 197 will sell R$228,239.01 in the next 6 weeks
# Store Number 199 will sell R$316,662.57 in the next 6 weeks
# Store Number 200 will sell R$266,564.62 in the next 6 weeks
# Store Number 201 will sell R$293,762.86 in the next 6 weeks
# Store Number 202 will sell R$193,900.46 in the next 6 weeks
# Store Number 204 will sell R$209,919.11 in the next 6 weeks
# Store Number 206 will sell R$293,028.17 in the next 6 weeks
# Store Number 207 will sell R$324,932.49 in the next 6 weeks
# Store Number 209 will sell R$224,379.24 in the next 6 weeks
# Store Number 210 will sell R$143,504.09 in the next 6 weeks
# Store Number 212 will sell R$205,309.56 in the next 6 weeks
# Store Number 213 will sell R$263,453.71 in the next 6 weeks
# Store Number 214 will sell R$325,536.09 in the next 6 weeks
# Store Number 215 will sell R$411,626.02 in the next 6 weeks
# Store Number 216 will sell R$421,778.89 in the next 6 weeks
# Store Number 217 will sell R$206,575.37 in the next 6 weeks
# Store Number 218 will sell R$241,898.43 in the next 6 weeks
# Store Number 219 will sell R$123,355.24 in the next 6 weeks
# Store Number 220 will sell R$230,227.55 in the next 6 weeks
# Store Number 221 will sell R$174,029.17 in the next 6 weeks
# Store Number 224 will sell R$212,654.85 in the next 6 weeks
# Store Number 226 will sell R$317,724.36 in the next 6 weeks
# Store Number 227 will sell R$279,273.85 in the next 6 weeks
# Store Number 228 will sell R$344,409.11 in the next 6 weeks
# Store Number 229 will sell R$304,210.79 in the next 6 weeks
# Store Number 230 will sell R$277,444.91 in the next 6 weeks
# Store Number 231 will sell R$234,629.54 in the next 6 weeks
# Store Number 233 will sell R$314,735.48 in the next 6 weeks
# Store Number 234 will sell R$345,492.71 in the next 6 weeks
# Store Number 235 will sell R$228,251.53 in the next 6 weeks
# Store Number 238 will sell R$462,563.42 in the next 6 weeks
# Store Number 239 will sell R$230,368.99 in the next 6 weeks
# Store Number 241 will sell R$260,582.55 in the next 6 weeks
# Store Number 242 will sell R$186,028.39 in the next 6 weeks
# Store Number 243 will sell R$328,583.36 in the next 6 weeks
# Store Number 244 will sell R$199,225.93 in the next 6 weeks
# Store Number 245 will sell R$288,817.46 in the next 6 weeks
# Store Number 246 will sell R$232,394.44 in the next 6 weeks
# Store Number 247 will sell R$227,562.59 in the next 6 weeks
# Store Number 248 will sell R$417,063.03 in the next 6 weeks
# Store Number 249 will sell R$179,046.32 in the next 6 weeks
# Store Number 250 will sell R$250,401.12 in the next 6 weeks
# Store Number 251 will sell R$476,135.51 in the next 6 weeks
# Store Number 252 will sell R$412,480.08 in the next 6 weeks
# Store Number 253 will sell R$250,530.82 in the next 6 weeks
# Store Number 254 will sell R$194,102.40 in the next 6 weeks
# Store Number 255 will sell R$266,305.34 in the next 6 weeks
# Store Number 256 will sell R$269,534.37 in the next 6 weeks
# Store Number 258 will sell R$216,087.64 in the next 6 weeks
# Store Number 259 will sell R$378,169.25 in the next 6 weeks
# Store Number 262 will sell R$547,705.40 in the next 6 weeks
# Store Number 263 will sell R$125,312.05 in the next 6 weeks
# Store Number 265 will sell R$209,750.31 in the next 6 weeks
# Store Number 267 will sell R$234,181.00 in the next 6 weeks
# Store Number 268 will sell R$158,175.75 in the next 6 weeks
# Store Number 269 will sell R$272,349.17 in the next 6 weeks
# Store Number 272 will sell R$207,674.45 in the next 6 weeks
# Store Number 273 will sell R$264,161.54 in the next 6 weeks
# Store Number 274 will sell R$227,774.65 in the next 6 weeks
# Store Number 275 will sell R$243,153.62 in the next 6 weeks
# Store Number 277 will sell R$245,972.82 in the next 6 weeks
# Store Number 278 will sell R$237,383.08 in the next 6 weeks
# Store Number 279 will sell R$311,087.60 in the next 6 weeks
# Store Number 280 will sell R$230,935.16 in the next 6 weeks
# Store Number 281 will sell R$229,260.12 in the next 6 weeks
# Store Number 283 will sell R$256,618.73 in the next 6 weeks
# Store Number 284 will sell R$205,750.29 in the next 6 weeks
# Store Number 285 will sell R$231,313.58 in the next 6 weeks
# Store Number 287 will sell R$300,853.74 in the next 6 weeks
# Store Number 288 will sell R$223,539.09 in the next 6 weeks
# Store Number 289 will sell R$230,616.45 in the next 6 weeks
# Store Number 290 will sell R$222,519.73 in the next 6 weeks
# Store Number 294 will sell R$224,521.17 in the next 6 weeks
# Store Number 295 will sell R$180,885.29 in the next 6 weeks
# Store Number 296 will sell R$249,406.19 in the next 6 weeks
# Store Number 297 will sell R$255,497.18 in the next 6 weeks
# Store Number 298 will sell R$293,450.57 in the next 6 weeks
# Store Number 299 will sell R$285,569.30 in the next 6 weeks
# Store Number 300 will sell R$242,540.90 in the next 6 weeks
# Store Number 301 will sell R$219,702.03 in the next 6 weeks
# Store Number 302 will sell R$176,568.69 in the next 6 weeks
# Store Number 303 will sell R$261,944.56 in the next 6 weeks
# Store Number 304 will sell R$247,174.43 in the next 6 weeks
# Store Number 305 will sell R$187,172.68 in the next 6 weeks
# Store Number 306 will sell R$179,943.52 in the next 6 weeks
# Store Number 308 will sell R$313,663.67 in the next 6 weeks
# Store Number 309 will sell R$297,460.91 in the next 6 weeks
# Store Number 310 will sell R$344,402.18 in the next 6 weeks
# Store Number 311 will sell R$274,206.03 in the next 6 weeks
# Store Number 312 will sell R$202,749.74 in the next 6 weeks
# Store Number 314 will sell R$174,982.11 in the next 6 weeks
# Store Number 315 will sell R$208,739.84 in the next 6 weeks
# Store Number 316 will sell R$318,630.08 in the next 6 weeks
# Store Number 317 will sell R$230,066.43 in the next 6 weeks
# Store Number 319 will sell R$363,645.75 in the next 6 weeks
# Store Number 320 will sell R$283,590.81 in the next 6 weeks
# Store Number 323 will sell R$289,851.13 in the next 6 weeks
# Store Number 325 will sell R$380,997.32 in the next 6 weeks
# Store Number 326 will sell R$202,348.12 in the next 6 weeks
# Store Number 328 will sell R$199,487.14 in the next 6 weeks
# Store Number 329 will sell R$250,698.60 in the next 6 weeks
# Store Number 330 will sell R$217,362.30 in the next 6 weeks
# Store Number 331 will sell R$300,707.24 in the next 6 weeks
# Store Number 333 will sell R$334,293.17 in the next 6 weeks
# Store Number 334 will sell R$224,379.87 in the next 6 weeks
# Store Number 335 will sell R$627,335.65 in the next 6 weeks
# Store Number 336 will sell R$354,649.79 in the next 6 weeks
# Store Number 337 will sell R$201,293.49 in the next 6 weeks
# Store Number 338 will sell R$289,341.21 in the next 6 weeks
# Store Number 339 will sell R$220,050.58 in the next 6 weeks
# Store Number 340 will sell R$307,166.08 in the next 6 weeks
# Store Number 341 will sell R$202,118.60 in the next 6 weeks
# Store Number 342 will sell R$394,438.19 in the next 6 weeks
# Store Number 343 will sell R$247,684.14 in the next 6 weeks
# Store Number 344 will sell R$287,887.54 in the next 6 weeks
# Store Number 345 will sell R$212,515.90 in the next 6 weeks
# Store Number 346 will sell R$272,584.49 in the next 6 weeks
# Store Number 347 will sell R$241,010.12 in the next 6 weeks
# Store Number 348 will sell R$203,842.81 in the next 6 weeks
# Store Number 350 will sell R$238,903.12 in the next 6 weeks
# Store Number 351 will sell R$234,965.77 in the next 6 weeks
# Store Number 352 will sell R$252,697.50 in the next 6 weeks
# Store Number 353 will sell R$336,860.18 in the next 6 weeks
# Store Number 354 will sell R$318,559.34 in the next 6 weeks
# Store Number 355 will sell R$335,488.96 in the next 6 weeks
# Store Number 356 will sell R$226,402.47 in the next 6 weeks
# Store Number 358 will sell R$406,363.03 in the next 6 weeks
# Store Number 359 will sell R$276,174.92 in the next 6 weeks
# Store Number 362 will sell R$387,610.35 in the next 6 weeks
# Store Number 364 will sell R$228,167.44 in the next 6 weeks
# Store Number 365 will sell R$229,757.45 in the next 6 weeks
# Store Number 367 will sell R$212,990.56 in the next 6 weeks
# Store Number 368 will sell R$360,354.13 in the next 6 weeks
# Store Number 369 will sell R$270,815.55 in the next 6 weeks
# Store Number 370 will sell R$310,352.63 in the next 6 weeks
# Store Number 371 will sell R$246,672.27 in the next 6 weeks
# Store Number 372 will sell R$332,604.04 in the next 6 weeks
# Store Number 373 will sell R$231,146.38 in the next 6 weeks
# Store Number 377 will sell R$278,492.92 in the next 6 weeks
# Store Number 378 will sell R$264,850.90 in the next 6 weeks
# Store Number 379 will sell R$173,452.14 in the next 6 weeks
# Store Number 380 will sell R$455,657.29 in the next 6 weeks
# Store Number 383 will sell R$478,915.14 in the next 6 weeks
# Store Number 385 will sell R$288,516.85 in the next 6 weeks
# Store Number 386 will sell R$269,380.83 in the next 6 weeks
# Store Number 387 will sell R$370,401.84 in the next 6 weeks
# Store Number 388 will sell R$387,589.19 in the next 6 weeks
# Store Number 389 will sell R$459,364.09 in the next 6 weeks
# Store Number 391 will sell R$322,289.51 in the next 6 weeks
# Store Number 392 will sell R$273,907.08 in the next 6 weeks
# Store Number 393 will sell R$246,490.51 in the next 6 weeks
# Store Number 394 will sell R$255,938.13 in the next 6 weeks
# Store Number 395 will sell R$188,267.27 in the next 6 weeks
# Store Number 397 will sell R$268,825.03 in the next 6 weeks
# Store Number 398 will sell R$228,440.45 in the next 6 weeks
# Store Number 399 will sell R$229,345.40 in the next 6 weeks
# Store Number 403 will sell R$302,974.03 in the next 6 weeks
# Store Number 404 will sell R$194,196.97 in the next 6 weeks
# Store Number 405 will sell R$177,977.87 in the next 6 weeks
# Store Number 406 will sell R$256,823.26 in the next 6 weeks
# Store Number 407 will sell R$158,942.01 in the next 6 weeks
# Store Number 408 will sell R$231,873.99 in the next 6 weeks
# Store Number 409 will sell R$190,406.83 in the next 6 weeks
# Store Number 410 will sell R$188,539.55 in the next 6 weeks
# Store Number 411 will sell R$342,129.84 in the next 6 weeks
# Store Number 412 will sell R$333,699.46 in the next 6 weeks
# Store Number 413 will sell R$297,560.48 in the next 6 weeks
# Store Number 414 will sell R$277,425.77 in the next 6 weeks
# Store Number 415 will sell R$234,540.74 in the next 6 weeks
# Store Number 416 will sell R$395,843.61 in the next 6 weeks
# Store Number 417 will sell R$238,180.95 in the next 6 weeks
# Store Number 418 will sell R$266,490.57 in the next 6 weeks
# Store Number 420 will sell R$230,778.11 in the next 6 weeks
# Store Number 421 will sell R$252,072.55 in the next 6 weeks
# Store Number 422 will sell R$295,389.42 in the next 6 weeks
# Store Number 424 will sell R$286,595.97 in the next 6 weeks
# Store Number 425 will sell R$244,950.74 in the next 6 weeks
# Store Number 426 will sell R$246,076.25 in the next 6 weeks
# Store Number 427 will sell R$234,050.74 in the next 6 weeks
# Store Number 428 will sell R$258,616.66 in the next 6 weeks
# Store Number 429 will sell R$194,557.99 in the next 6 weeks
# Store Number 430 will sell R$204,352.52 in the next 6 weeks
# Store Number 431 will sell R$390,857.46 in the next 6 weeks
# Store Number 432 will sell R$366,957.83 in the next 6 weeks
# Store Number 433 will sell R$214,948.07 in the next 6 weeks
# Store Number 434 will sell R$164,824.68 in the next 6 weeks
# Store Number 435 will sell R$232,290.19 in the next 6 weeks
# Store Number 440 will sell R$235,358.95 in the next 6 weeks
# Store Number 441 will sell R$259,731.07 in the next 6 weeks
# Store Number 442 will sell R$288,208.77 in the next 6 weeks
# Store Number 445 will sell R$296,758.15 in the next 6 weeks
# Store Number 446 will sell R$250,051.91 in the next 6 weeks
# Store Number 447 will sell R$279,971.69 in the next 6 weeks
# Store Number 448 will sell R$298,822.41 in the next 6 weeks
# Store Number 449 will sell R$554,146.44 in the next 6 weeks
# Store Number 450 will sell R$307,825.14 in the next 6 weeks
# Store Number 451 will sell R$170,791.24 in the next 6 weeks
# Store Number 452 will sell R$225,562.40 in the next 6 weeks
# Store Number 453 will sell R$317,829.87 in the next 6 weeks
# Store Number 455 will sell R$264,333.99 in the next 6 weeks
# Store Number 456 will sell R$264,564.67 in the next 6 weeks
# Store Number 457 will sell R$168,007.80 in the next 6 weeks
# Store Number 458 will sell R$294,350.66 in the next 6 weeks
# Store Number 459 will sell R$237,851.14 in the next 6 weeks
# Store Number 461 will sell R$183,808.38 in the next 6 weeks
# Store Number 463 will sell R$273,540.09 in the next 6 weeks
# Store Number 465 will sell R$170,535.65 in the next 6 weeks
# Store Number 466 will sell R$309,987.58 in the next 6 weeks
# Store Number 467 will sell R$445,639.29 in the next 6 weeks
# Store Number 468 will sell R$248,278.01 in the next 6 weeks
# Store Number 470 will sell R$371,973.26 in the next 6 weeks
# Store Number 471 will sell R$296,110.75 in the next 6 weeks
# Store Number 472 will sell R$211,310.20 in the next 6 weeks
# Store Number 473 will sell R$165,150.49 in the next 6 weeks
# Store Number 475 will sell R$168,946.82 in the next 6 weeks
# Store Number 477 will sell R$190,972.11 in the next 6 weeks
# Store Number 481 will sell R$212,048.87 in the next 6 weeks
# Store Number 484 will sell R$171,738.47 in the next 6 weeks
# Store Number 485 will sell R$208,282.31 in the next 6 weeks
# Store Number 486 will sell R$196,461.49 in the next 6 weeks
# Store Number 487 will sell R$248,341.83 in the next 6 weeks
# Store Number 488 will sell R$227,870.29 in the next 6 weeks
# Store Number 490 will sell R$247,705.54 in the next 6 weeks
# Store Number 491 will sell R$274,470.38 in the next 6 weeks
# Store Number 492 will sell R$262,122.62 in the next 6 weeks
# Store Number 493 will sell R$241,628.02 in the next 6 weeks
# Store Number 495 will sell R$230,836.39 in the next 6 weeks
# Store Number 497 will sell R$310,396.37 in the next 6 weeks
# Store Number 498 will sell R$344,556.79 in the next 6 weeks
# Store Number 499 will sell R$284,420.09 in the next 6 weeks
# Store Number 500 will sell R$190,933.98 in the next 6 weeks
# Store Number 501 will sell R$237,679.35 in the next 6 weeks
# Store Number 502 will sell R$340,260.24 in the next 6 weeks
# Store Number 504 will sell R$408,295.52 in the next 6 weeks
# Store Number 505 will sell R$221,437.13 in the next 6 weeks
# Store Number 506 will sell R$323,868.41 in the next 6 weeks
# Store Number 507 will sell R$329,852.90 in the next 6 weeks
# Store Number 508 will sell R$310,847.61 in the next 6 weeks
# Store Number 509 will sell R$239,174.65 in the next 6 weeks
# Store Number 510 will sell R$311,615.05 in the next 6 weeks
# Store Number 511 will sell R$267,974.81 in the next 6 weeks
# Store Number 512 will sell R$360,331.08 in the next 6 weeks
# Store Number 514 will sell R$239,478.07 in the next 6 weeks
# Store Number 515 will sell R$378,432.10 in the next 6 weeks
# Store Number 516 will sell R$310,497.66 in the next 6 weeks
# Store Number 517 will sell R$335,890.34 in the next 6 weeks
# Store Number 518 will sell R$243,230.57 in the next 6 weeks
# Store Number 519 will sell R$199,194.56 in the next 6 weeks
# Store Number 520 will sell R$199,968.20 in the next 6 weeks
# Store Number 521 will sell R$205,069.78 in the next 6 weeks
# Store Number 522 will sell R$363,407.73 in the next 6 weeks
# Store Number 524 will sell R$292,602.05 in the next 6 weeks
# Store Number 527 will sell R$357,864.11 in the next 6 weeks
# Store Number 528 will sell R$465,263.12 in the next 6 weeks
# Store Number 529 will sell R$204,458.87 in the next 6 weeks
# Store Number 530 will sell R$227,876.16 in the next 6 weeks
# Store Number 531 will sell R$227,844.45 in the next 6 weeks
# Store Number 532 will sell R$407,520.54 in the next 6 weeks
# Store Number 533 will sell R$404,379.60 in the next 6 weeks
# Store Number 534 will sell R$269,469.95 in the next 6 weeks
# Store Number 535 will sell R$248,519.95 in the next 6 weeks
# Store Number 536 will sell R$317,586.69 in the next 6 weeks
# Store Number 537 will sell R$212,231.13 in the next 6 weeks
# Store Number 538 will sell R$186,835.83 in the next 6 weeks
# Store Number 539 will sell R$323,497.79 in the next 6 weeks
# Store Number 540 will sell R$285,096.25 in the next 6 weeks
# Store Number 541 will sell R$455,210.58 in the next 6 weeks
# Store Number 542 will sell R$219,441.25 in the next 6 weeks
# Store Number 543 will sell R$133,515.80 in the next 6 weeks
# Store Number 545 will sell R$313,104.06 in the next 6 weeks
# Store Number 547 will sell R$241,510.12 in the next 6 weeks
# Store Number 548 will sell R$217,682.23 in the next 6 weeks
# Store Number 549 will sell R$259,696.63 in the next 6 weeks
# Store Number 550 will sell R$255,472.27 in the next 6 weeks
# Store Number 551 will sell R$231,973.35 in the next 6 weeks
# Store Number 552 will sell R$301,623.66 in the next 6 weeks
# Store Number 553 will sell R$259,529.47 in the next 6 weeks
# Store Number 554 will sell R$236,558.88 in the next 6 weeks
# Store Number 555 will sell R$182,281.44 in the next 6 weeks
# Store Number 557 will sell R$190,932.50 in the next 6 weeks
# Store Number 558 will sell R$126,266.07 in the next 6 weeks
# Store Number 561 will sell R$187,578.19 in the next 6 weeks
# Store Number 562 will sell R$700,841.18 in the next 6 weeks
# Store Number 563 will sell R$216,219.51 in the next 6 weeks
# Store Number 564 will sell R$227,391.39 in the next 6 weeks
# Store Number 565 will sell R$212,663.43 in the next 6 weeks
# Store Number 566 will sell R$230,515.01 in the next 6 weeks
# Store Number 567 will sell R$241,916.86 in the next 6 weeks
# Store Number 568 will sell R$227,506.24 in the next 6 weeks
# Store Number 570 will sell R$142,225.83 in the next 6 weeks
# Store Number 571 will sell R$244,504.32 in the next 6 weeks
# Store Number 572 will sell R$290,723.00 in the next 6 weeks
# Store Number 573 will sell R$164,490.01 in the next 6 weeks
# Store Number 574 will sell R$356,698.10 in the next 6 weeks
# Store Number 575 will sell R$244,228.41 in the next 6 weeks
# Store Number 577 will sell R$232,031.47 in the next 6 weeks
# Store Number 578 will sell R$234,976.12 in the next 6 weeks
# Store Number 579 will sell R$337,020.44 in the next 6 weeks
# Store Number 580 will sell R$271,678.18 in the next 6 weeks
# Store Number 581 will sell R$174,421.28 in the next 6 weeks
# Store Number 582 will sell R$283,930.17 in the next 6 weeks
# Store Number 584 will sell R$278,101.75 in the next 6 weeks
# Store Number 585 will sell R$234,426.71 in the next 6 weeks
# Store Number 586 will sell R$299,986.28 in the next 6 weeks
# Store Number 587 will sell R$463,996.75 in the next 6 weeks
# Store Number 588 will sell R$234,143.03 in the next 6 weeks
# Store Number 589 will sell R$303,668.12 in the next 6 weeks
# Store Number 590 will sell R$197,889.59 in the next 6 weeks
# Store Number 591 will sell R$222,549.96 in the next 6 weeks
# Store Number 592 will sell R$163,097.99 in the next 6 weeks
# Store Number 593 will sell R$209,173.30 in the next 6 weeks
# Store Number 597 will sell R$180,543.18 in the next 6 weeks
# Store Number 598 will sell R$188,295.33 in the next 6 weeks
# Store Number 600 will sell R$269,910.75 in the next 6 weeks
# Store Number 601 will sell R$223,927.60 in the next 6 weeks
# Store Number 602 will sell R$238,011.81 in the next 6 weeks
# Store Number 603 will sell R$354,450.04 in the next 6 weeks
# Store Number 604 will sell R$173,228.09 in the next 6 weeks
# Store Number 605 will sell R$281,756.53 in the next 6 weeks
# Store Number 610 will sell R$180,787.41 in the next 6 weeks
# Store Number 611 will sell R$220,874.93 in the next 6 weeks
# Store Number 612 will sell R$231,961.33 in the next 6 weeks
# Store Number 615 will sell R$312,132.68 in the next 6 weeks
# Store Number 616 will sell R$311,298.35 in the next 6 weeks
# Store Number 618 will sell R$249,302.16 in the next 6 weeks
# Store Number 619 will sell R$186,359.61 in the next 6 weeks
# Store Number 620 will sell R$283,890.90 in the next 6 weeks
# Store Number 621 will sell R$207,241.58 in the next 6 weeks
# Store Number 622 will sell R$101,994.16 in the next 6 weeks
# Store Number 623 will sell R$278,869.92 in the next 6 weeks
# Store Number 624 will sell R$272,956.14 in the next 6 weeks
# Store Number 625 will sell R$222,239.45 in the next 6 weeks
# Store Number 627 will sell R$221,958.67 in the next 6 weeks
# Store Number 628 will sell R$269,540.69 in the next 6 weeks
# Store Number 629 will sell R$268,403.35 in the next 6 weeks
# Store Number 631 will sell R$278,466.07 in the next 6 weeks
# Store Number 632 will sell R$197,754.16 in the next 6 weeks
# Store Number 633 will sell R$244,493.42 in the next 6 weeks
# Store Number 636 will sell R$227,307.92 in the next 6 weeks
# Store Number 637 will sell R$361,826.76 in the next 6 weeks
# Store Number 638 will sell R$210,659.60 in the next 6 weeks
# Store Number 639 will sell R$235,729.18 in the next 6 weeks
# Store Number 640 will sell R$369,784.07 in the next 6 weeks
# Store Number 641 will sell R$253,875.76 in the next 6 weeks
# Store Number 642 will sell R$223,890.48 in the next 6 weeks
# Store Number 643 will sell R$268,210.90 in the next 6 weeks
# Store Number 644 will sell R$356,040.84 in the next 6 weeks
# Store Number 645 will sell R$485,506.66 in the next 6 weeks
# Store Number 646 will sell R$181,701.87 in the next 6 weeks
# Store Number 647 will sell R$253,089.28 in the next 6 weeks
# Store Number 650 will sell R$192,333.90 in the next 6 weeks
# Store Number 651 will sell R$283,655.20 in the next 6 weeks
# Store Number 653 will sell R$266,724.85 in the next 6 weeks
# Store Number 655 will sell R$283,230.16 in the next 6 weeks
# Store Number 656 will sell R$202,414.50 in the next 6 weeks
# Store Number 657 will sell R$190,841.62 in the next 6 weeks
# Store Number 658 will sell R$346,188.55 in the next 6 weeks
# Store Number 659 will sell R$242,050.23 in the next 6 weeks
# Store Number 660 will sell R$183,379.54 in the next 6 weeks
# Store Number 661 will sell R$267,393.49 in the next 6 weeks
# Store Number 662 will sell R$326,471.25 in the next 6 weeks
# Store Number 663 will sell R$172,040.13 in the next 6 weeks
# Store Number 665 will sell R$237,010.08 in the next 6 weeks
# Store Number 666 will sell R$270,152.01 in the next 6 weeks
# Store Number 667 will sell R$402,383.98 in the next 6 weeks
# Store Number 669 will sell R$200,546.96 in the next 6 weeks
# Store Number 670 will sell R$295,898.94 in the next 6 weeks
# Store Number 671 will sell R$330,212.16 in the next 6 weeks
# Store Number 673 will sell R$287,143.45 in the next 6 weeks
# Store Number 674 will sell R$291,104.60 in the next 6 weeks
# Store Number 675 will sell R$179,012.97 in the next 6 weeks
# Store Number 676 will sell R$557,724.03 in the next 6 weeks
# Store Number 677 will sell R$243,020.98 in the next 6 weeks
# Store Number 678 will sell R$298,868.37 in the next 6 weeks
# Store Number 680 will sell R$281,624.94 in the next 6 weeks
# Store Number 681 will sell R$165,199.06 in the next 6 weeks
# Store Number 684 will sell R$288,277.14 in the next 6 weeks
# Store Number 685 will sell R$351,457.08 in the next 6 weeks
# Store Number 687 will sell R$369,084.90 in the next 6 weeks
# Store Number 689 will sell R$278,068.53 in the next 6 weeks
# Store Number 690 will sell R$283,816.17 in the next 6 weeks
# Store Number 691 will sell R$326,768.62 in the next 6 weeks
# Store Number 692 will sell R$197,422.30 in the next 6 weeks
# Store Number 693 will sell R$334,840.94 in the next 6 weeks
# Store Number 694 will sell R$452,866.27 in the next 6 weeks
# Store Number 695 will sell R$201,041.85 in the next 6 weeks
# Store Number 696 will sell R$355,095.83 in the next 6 weeks
# Store Number 697 will sell R$331,815.79 in the next 6 weeks
# Store Number 699 will sell R$343,473.82 in the next 6 weeks
# Store Number 700 will sell R$172,341.48 in the next 6 weeks
# Store Number 701 will sell R$228,325.12 in the next 6 weeks
# Store Number 702 will sell R$184,100.08 in the next 6 weeks
# Store Number 703 will sell R$102,832.63 in the next 6 weeks
# Store Number 705 will sell R$286,683.00 in the next 6 weeks
# Store Number 706 will sell R$236,960.47 in the next 6 weeks
# Store Number 707 will sell R$309,125.85 in the next 6 weeks
# Store Number 710 will sell R$208,260.74 in the next 6 weeks
# Store Number 711 will sell R$283,258.57 in the next 6 weeks
# Store Number 712 will sell R$249,601.88 in the next 6 weeks
# Store Number 713 will sell R$355,238.74 in the next 6 weeks
# Store Number 714 will sell R$203,438.38 in the next 6 weeks
# Store Number 716 will sell R$214,777.03 in the next 6 weeks
# Store Number 717 will sell R$414,969.95 in the next 6 weeks
# Store Number 718 will sell R$240,421.52 in the next 6 weeks
# Store Number 719 will sell R$237,235.21 in the next 6 weeks
# Store Number 720 will sell R$295,237.87 in the next 6 weeks
# Store Number 721 will sell R$384,038.52 in the next 6 weeks
# Store Number 722 will sell R$357,110.35 in the next 6 weeks
# Store Number 723 will sell R$273,789.26 in the next 6 weeks
# Store Number 724 will sell R$285,432.54 in the next 6 weeks
# Store Number 725 will sell R$276,451.16 in the next 6 weeks
# Store Number 727 will sell R$217,124.61 in the next 6 weeks
# Store Number 728 will sell R$202,621.34 in the next 6 weeks
# Store Number 729 will sell R$353,359.71 in the next 6 weeks
# Store Number 731 will sell R$337,678.20 in the next 6 weeks
# Store Number 732 will sell R$244,564.18 in the next 6 weeks
# Store Number 733 will sell R$453,086.37 in the next 6 weeks
# Store Number 734 will sell R$296,379.34 in the next 6 weeks
# Store Number 736 will sell R$220,892.39 in the next 6 weeks
# Store Number 737 will sell R$249,080.29 in the next 6 weeks
# Store Number 738 will sell R$314,943.35 in the next 6 weeks
# Store Number 739 will sell R$368,714.19 in the next 6 weeks
# Store Number 740 will sell R$266,183.01 in the next 6 weeks
# Store Number 741 will sell R$231,563.74 in the next 6 weeks
# Store Number 742 will sell R$340,970.27 in the next 6 weeks
# Store Number 744 will sell R$272,969.04 in the next 6 weeks
# Store Number 746 will sell R$246,062.62 in the next 6 weeks
# Store Number 748 will sell R$242,365.11 in the next 6 weeks
# Store Number 749 will sell R$233,164.43 in the next 6 weeks
# Store Number 750 will sell R$201,276.39 in the next 6 weeks
# Store Number 751 will sell R$259,467.92 in the next 6 weeks
# Store Number 752 will sell R$222,986.18 in the next 6 weeks
# Store Number 753 will sell R$401,084.48 in the next 6 weeks
# Store Number 756 will sell R$412,161.64 in the next 6 weeks
# Store Number 757 will sell R$308,027.30 in the next 6 weeks
# Store Number 758 will sell R$268,065.78 in the next 6 weeks
# Store Number 759 will sell R$230,178.15 in the next 6 weeks
# Store Number 762 will sell R$223,109.50 in the next 6 weeks
# Store Number 763 will sell R$165,382.04 in the next 6 weeks
# Store Number 764 will sell R$129,463.83 in the next 6 weeks
# Store Number 765 will sell R$333,676.61 in the next 6 weeks
# Store Number 766 will sell R$208,122.05 in the next 6 weeks
# Store Number 767 will sell R$149,994.34 in the next 6 weeks
# Store Number 768 will sell R$432,141.03 in the next 6 weeks
# Store Number 769 will sell R$383,789.58 in the next 6 weeks
# Store Number 770 will sell R$323,969.87 in the next 6 weeks
# Store Number 771 will sell R$279,349.73 in the next 6 weeks
# Store Number 772 will sell R$261,838.07 in the next 6 weeks
# Store Number 773 will sell R$265,503.76 in the next 6 weeks
# Store Number 774 will sell R$329,041.47 in the next 6 weeks
# Store Number 775 will sell R$348,368.73 in the next 6 weeks
# Store Number 776 will sell R$222,735.05 in the next 6 weeks
# Store Number 777 will sell R$181,610.38 in the next 6 weeks
# Store Number 778 will sell R$326,280.79 in the next 6 weeks
# Store Number 782 will sell R$218,944.67 in the next 6 weeks
# Store Number 784 will sell R$202,552.47 in the next 6 weeks
# Store Number 785 will sell R$196,893.96 in the next 6 weeks
# Store Number 789 will sell R$124,501.12 in the next 6 weeks
# Store Number 790 will sell R$207,979.35 in the next 6 weeks
# Store Number 791 will sell R$234,313.07 in the next 6 weeks
# Store Number 792 will sell R$283,701.74 in the next 6 weeks
# Store Number 793 will sell R$181,632.61 in the next 6 weeks
# Store Number 795 will sell R$194,091.21 in the next 6 weeks
# Store Number 796 will sell R$275,407.28 in the next 6 weeks
# Store Number 797 will sell R$155,427.66 in the next 6 weeks
# Store Number 799 will sell R$334,493.58 in the next 6 weeks
# Store Number 800 will sell R$224,883.37 in the next 6 weeks
# Store Number 801 will sell R$171,005.09 in the next 6 weeks
# Store Number 802 will sell R$260,999.15 in the next 6 weeks
# Store Number 803 will sell R$259,008.76 in the next 6 weeks
# Store Number 804 will sell R$216,527.53 in the next 6 weeks
# Store Number 805 will sell R$161,614.48 in the next 6 weeks
# Store Number 806 will sell R$391,024.74 in the next 6 weeks
# Store Number 807 will sell R$313,647.76 in the next 6 weeks
# Store Number 809 will sell R$221,761.20 in the next 6 weeks
# Store Number 810 will sell R$231,146.26 in the next 6 weeks
# Store Number 811 will sell R$275,883.75 in the next 6 weeks
# Store Number 813 will sell R$252,804.12 in the next 6 weeks
# Store Number 815 will sell R$436,687.82 in the next 6 weeks
# Store Number 816 will sell R$323,726.88 in the next 6 weeks
# Store Number 818 will sell R$234,515.43 in the next 6 weeks
# Store Number 819 will sell R$296,782.37 in the next 6 weeks
# Store Number 820 will sell R$333,652.02 in the next 6 weeks
# Store Number 822 will sell R$492,925.55 in the next 6 weeks
# Store Number 823 will sell R$223,909.57 in the next 6 weeks
# Store Number 824 will sell R$246,103.63 in the next 6 weeks
# Store Number 825 will sell R$256,478.60 in the next 6 weeks
# Store Number 826 will sell R$267,650.33 in the next 6 weeks
# Store Number 829 will sell R$276,180.37 in the next 6 weeks
# Store Number 831 will sell R$318,042.90 in the next 6 weeks
# Store Number 832 will sell R$239,975.97 in the next 6 weeks
# Store Number 833 will sell R$228,882.00 in the next 6 weeks
# Store Number 835 will sell R$241,057.32 in the next 6 weeks
# Store Number 837 will sell R$268,734.66 in the next 6 weeks
# Store Number 840 will sell R$248,067.29 in the next 6 weeks
# Store Number 842 will sell R$487,163.07 in the next 6 weeks
# Store Number 844 will sell R$203,632.38 in the next 6 weeks
# Store Number 845 will sell R$202,603.16 in the next 6 weeks
# Store Number 846 will sell R$385,831.06 in the next 6 weeks
# Store Number 847 will sell R$299,262.91 in the next 6 weeks
# Store Number 848 will sell R$363,142.54 in the next 6 weeks
# Store Number 849 will sell R$281,191.90 in the next 6 weeks
# Store Number 850 will sell R$195,552.45 in the next 6 weeks
# Store Number 851 will sell R$232,968.05 in the next 6 weeks
# Store Number 852 will sell R$207,115.61 in the next 6 weeks
# Store Number 853 will sell R$180,373.94 in the next 6 weeks
# Store Number 855 will sell R$261,613.04 in the next 6 weeks
# Store Number 856 will sell R$215,449.47 in the next 6 weeks
# Store Number 857 will sell R$269,244.03 in the next 6 weeks
# Store Number 858 will sell R$167,154.92 in the next 6 weeks
# Store Number 859 will sell R$349,943.34 in the next 6 weeks
# Store Number 860 will sell R$190,623.98 in the next 6 weeks
# Store Number 861 will sell R$196,245.29 in the next 6 weeks
# Store Number 862 will sell R$365,867.09 in the next 6 weeks
# Store Number 863 will sell R$236,511.04 in the next 6 weeks
# Store Number 864 will sell R$205,412.29 in the next 6 weeks
# Store Number 865 will sell R$307,120.99 in the next 6 weeks
# Store Number 866 will sell R$276,449.69 in the next 6 weeks
# Store Number 867 will sell R$292,296.75 in the next 6 weeks
# Store Number 868 will sell R$392,291.06 in the next 6 weeks
# Store Number 871 will sell R$266,058.40 in the next 6 weeks
# Store Number 872 will sell R$263,031.95 in the next 6 weeks
# Store Number 874 will sell R$213,160.62 in the next 6 weeks
# Store Number 875 will sell R$187,320.36 in the next 6 weeks
# Store Number 877 will sell R$211,348.04 in the next 6 weeks
# Store Number 879 will sell R$130,422.81 in the next 6 weeks
# Store Number 880 will sell R$335,549.37 in the next 6 weeks
# Store Number 881 will sell R$229,075.79 in the next 6 weeks
# Store Number 882 will sell R$228,954.00 in the next 6 weeks
# Store Number 883 will sell R$167,553.99 in the next 6 weeks
# Store Number 884 will sell R$251,288.81 in the next 6 weeks
# Store Number 885 will sell R$254,681.64 in the next 6 weeks
# Store Number 886 will sell R$268,951.83 in the next 6 weeks
# Store Number 887 will sell R$365,922.12 in the next 6 weeks
# Store Number 888 will sell R$312,279.71 in the next 6 weeks
# Store Number 890 will sell R$222,925.77 in the next 6 weeks
# Store Number 891 will sell R$346,270.91 in the next 6 weeks
# Store Number 893 will sell R$291,806.27 in the next 6 weeks
# Store Number 894 will sell R$195,717.56 in the next 6 weeks
# Store Number 895 will sell R$348,611.29 in the next 6 weeks
# Store Number 896 will sell R$206,385.74 in the next 6 weeks
# Store Number 897 will sell R$153,982.26 in the next 6 weeks
# Store Number 900 will sell R$242,265.34 in the next 6 weeks
# Store Number 901 will sell R$240,531.12 in the next 6 weeks
# Store Number 902 will sell R$286,750.97 in the next 6 weeks
# Store Number 903 will sell R$292,924.69 in the next 6 weeks
# Store Number 904 will sell R$315,938.31 in the next 6 weeks
# Store Number 905 will sell R$221,026.79 in the next 6 weeks
# Store Number 906 will sell R$278,107.38 in the next 6 weeks
# Store Number 907 will sell R$291,626.15 in the next 6 weeks
# Store Number 908 will sell R$192,229.36 in the next 6 weeks
# Store Number 909 will sell R$370,621.65 in the next 6 weeks
# Store Number 911 will sell R$300,685.85 in the next 6 weeks
# Store Number 912 will sell R$261,806.12 in the next 6 weeks
# Store Number 913 will sell R$275,855.39 in the next 6 weeks
# Store Number 914 will sell R$350,526.17 in the next 6 weeks
# Store Number 915 will sell R$325,352.19 in the next 6 weeks
# Store Number 916 will sell R$153,735.41 in the next 6 weeks
# Store Number 917 will sell R$197,601.12 in the next 6 weeks
# Store Number 919 will sell R$212,797.28 in the next 6 weeks
# Store Number 920 will sell R$195,176.36 in the next 6 weeks
# Store Number 922 will sell R$223,133.28 in the next 6 weeks
# Store Number 924 will sell R$194,049.74 in the next 6 weeks
# Store Number 925 will sell R$303,971.63 in the next 6 weeks
# Store Number 926 will sell R$291,863.92 in the next 6 weeks
# Store Number 927 will sell R$335,099.88 in the next 6 weeks
# Store Number 928 will sell R$283,172.54 in the next 6 weeks
# Store Number 929 will sell R$243,329.70 in the next 6 weeks
# Store Number 930 will sell R$259,919.33 in the next 6 weeks
# Store Number 931 will sell R$202,334.30 in the next 6 weeks
# Store Number 932 will sell R$306,487.83 in the next 6 weeks
# Store Number 934 will sell R$255,208.83 in the next 6 weeks
# Store Number 935 will sell R$317,421.36 in the next 6 weeks
# Store Number 936 will sell R$256,758.29 in the next 6 weeks
# Store Number 937 will sell R$312,352.54 in the next 6 weeks
# Store Number 938 will sell R$240,664.40 in the next 6 weeks
# Store Number 939 will sell R$293,428.70 in the next 6 weeks
# Store Number 941 will sell R$180,583.24 in the next 6 weeks
# Store Number 942 will sell R$284,520.42 in the next 6 weeks
# Store Number 943 will sell R$227,497.81 in the next 6 weeks
# Store Number 944 will sell R$235,077.75 in the next 6 weeks
# Store Number 945 will sell R$202,580.44 in the next 6 weeks
# Store Number 946 will sell R$157,624.24 in the next 6 weeks
# Store Number 947 will sell R$346,820.60 in the next 6 weeks
# Store Number 948 will sell R$408,976.15 in the next 6 weeks
# Store Number 950 will sell R$204,101.81 in the next 6 weeks
# Store Number 951 will sell R$309,361.02 in the next 6 weeks
# Store Number 952 will sell R$248,942.03 in the next 6 weeks
# Store Number 954 will sell R$297,211.25 in the next 6 weeks
# Store Number 955 will sell R$168,380.85 in the next 6 weeks
# Store Number 956 will sell R$159,950.65 in the next 6 weeks
# Store Number 960 will sell R$270,248.73 in the next 6 weeks
# Store Number 961 will sell R$257,009.64 in the next 6 weeks
# Store Number 962 will sell R$271,825.81 in the next 6 weeks
# Store Number 964 will sell R$324,223.28 in the next 6 weeks
# Store Number 965 will sell R$302,845.89 in the next 6 weeks
# Store Number 966 will sell R$213,380.26 in the next 6 weeks
# Store Number 967 will sell R$282,680.81 in the next 6 weeks
# Store Number 969 will sell R$176,449.87 in the next 6 weeks
# Store Number 970 will sell R$169,546.93 in the next 6 weeks
# Store Number 973 will sell R$319,682.01 in the next 6 weeks
# Store Number 974 will sell R$305,723.03 in the next 6 weeks
# Store Number 975 will sell R$278,304.79 in the next 6 weeks
# Store Number 976 will sell R$261,486.20 in the next 6 weeks
# Store Number 977 will sell R$250,781.89 in the next 6 weeks
# Store Number 980 will sell R$278,100.30 in the next 6 weeks
# Store Number 983 will sell R$236,854.92 in the next 6 weeks
# Store Number 984 will sell R$301,791.20 in the next 6 weeks
# Store Number 985 will sell R$361,505.16 in the next 6 weeks
# Store Number 986 will sell R$172,410.01 in the next 6 weeks
# Store Number 988 will sell R$180,477.39 in the next 6 weeks
# Store Number 989 will sell R$204,040.32 in the next 6 weeks
# Store Number 991 will sell R$238,989.28 in the next 6 weeks
# Store Number 992 will sell R$202,729.36 in the next 6 weeks
# Store Number 994 will sell R$164,784.03 in the next 6 weeks
# Store Number 997 will sell R$207,987.36 in the next 6 weeks
# Store Number 998 will sell R$171,429.82 in the next 6 weeks
# Store Number 1000 will sell R$249,094.71 in the next 6 weeks
# Store Number 1003 will sell R$219,158.87 in the next 6 weeks
# Store Number 1004 will sell R$175,356.66 in the next 6 weeks
# Store Number 1005 will sell R$267,240.42 in the next 6 weeks
# Store Number 1007 will sell R$257,810.18 in the next 6 weeks
# Store Number 1008 will sell R$206,025.44 in the next 6 weeks
# Store Number 1009 will sell R$181,514.70 in the next 6 weeks
# Store Number 1010 will sell R$351,789.98 in the next 6 weeks
# Store Number 1011 will sell R$408,398.30 in the next 6 weeks
# Store Number 1012 will sell R$233,063.38 in the next 6 weeks
# Store Number 1013 will sell R$179,116.44 in the next 6 weeks
# Store Number 1014 will sell R$299,142.21 in the next 6 weeks
# Store Number 1015 will sell R$247,538.55 in the next 6 weeks
# Store Number 1016 will sell R$319,815.52 in the next 6 weeks
# Store Number 1019 will sell R$332,548.26 in the next 6 weeks
# Store Number 1020 will sell R$250,919.53 in the next 6 weeks
# Store Number 1022 will sell R$336,100.57 in the next 6 weeks
# Store Number 1024 will sell R$201,732.82 in the next 6 weeks
# Store Number 1025 will sell R$256,056.01 in the next 6 weeks
# Store Number 1026 will sell R$379,009.92 in the next 6 weeks
# Store Number 1027 will sell R$327,218.40 in the next 6 weeks
# Store Number 1028 will sell R$231,752.83 in the next 6 weeks
# Store Number 1031 will sell R$265,343.65 in the next 6 weeks
# Store Number 1036 will sell R$222,285.29 in the next 6 weeks
# Store Number 1037 will sell R$250,973.05 in the next 6 weeks
# Store Number 1038 will sell R$247,499.27 in the next 6 weeks
# Store Number 1039 will sell R$250,274.38 in the next 6 weeks
# Store Number 1040 will sell R$327,516.94 in the next 6 weeks
# Store Number 1041 will sell R$254,912.55 in the next 6 weeks
# Store Number 1042 will sell R$216,439.93 in the next 6 weeks
# Store Number 1044 will sell R$318,897.85 in the next 6 weeks
# Store Number 1045 will sell R$262,127.49 in the next 6 weeks
# Store Number 1047 will sell R$242,911.15 in the next 6 weeks
# Store Number 1048 will sell R$265,007.19 in the next 6 weeks
# Store Number 1049 will sell R$214,861.83 in the next 6 weeks
# Store Number 1050 will sell R$280,572.12 in the next 6 weeks
# Store Number 1051 will sell R$224,753.38 in the next 6 weeks
# Store Number 1052 will sell R$301,979.23 in the next 6 weeks
# Store Number 1053 will sell R$342,226.18 in the next 6 weeks
# Store Number 1054 will sell R$226,788.48 in the next 6 weeks
# Store Number 1056 will sell R$181,913.08 in the next 6 weeks
# Store Number 1057 will sell R$241,165.04 in the next 6 weeks
# Store Number 1058 will sell R$275,772.60 in the next 6 weeks
# Store Number 1059 will sell R$287,849.66 in the next 6 weeks
# Store Number 1060 will sell R$322,836.21 in the next 6 weeks
# Store Number 1061 will sell R$319,668.80 in the next 6 weeks
# Store Number 1062 will sell R$164,115.25 in the next 6 weeks
# Store Number 1063 will sell R$212,460.62 in the next 6 weeks
# Store Number 1064 will sell R$341,334.84 in the next 6 weeks
# Store Number 1065 will sell R$191,910.95 in the next 6 weeks
# Store Number 1066 will sell R$337,622.38 in the next 6 weeks
# Store Number 1067 will sell R$204,593.41 in the next 6 weeks
# Store Number 1068 will sell R$197,999.18 in the next 6 weeks
# Store Number 1070 will sell R$268,653.59 in the next 6 weeks
# Store Number 1071 will sell R$259,784.96 in the next 6 weeks
# Store Number 1072 will sell R$284,313.19 in the next 6 weeks
# Store Number 1073 will sell R$330,459.41 in the next 6 weeks
# Store Number 1076 will sell R$173,326.16 in the next 6 weeks
# Store Number 1077 will sell R$176,713.18 in the next 6 weeks
# Store Number 1078 will sell R$306,947.19 in the next 6 weeks
# Store Number 1079 will sell R$322,209.31 in the next 6 weeks
# Store Number 1080 will sell R$341,367.60 in the next 6 weeks
# Store Number 1083 will sell R$249,612.19 in the next 6 weeks
# Store Number 1084 will sell R$250,663.33 in the next 6 weeks
# Store Number 1086 will sell R$170,343.09 in the next 6 weeks
# Store Number 1087 will sell R$209,222.32 in the next 6 weeks
# Store Number 1088 will sell R$201,441.01 in the next 6 weeks
# Store Number 1089 will sell R$349,438.46 in the next 6 weeks
# Store Number 1091 will sell R$307,188.44 in the next 6 weeks
# Store Number 1092 will sell R$316,860.89 in the next 6 weeks
# Store Number 1094 will sell R$184,713.74 in the next 6 weeks
# Store Number 1096 will sell R$184,138.68 in the next 6 weeks
# Store Number 1097 will sell R$401,585.10 in the next 6 weeks
# Store Number 1099 will sell R$218,607.02 in the next 6 weeks
# Store Number 1100 will sell R$275,538.26 in the next 6 weeks
# Store Number 1101 will sell R$379,392.08 in the next 6 weeks
# Store Number 1102 will sell R$244,795.75 in the next 6 weeks
# Store Number 1103 will sell R$213,530.64 in the next 6 weeks
# Store Number 1104 will sell R$172,841.79 in the next 6 weeks
# Store Number 1105 will sell R$192,021.10 in the next 6 weeks
# Store Number 1106 will sell R$189,839.85 in the next 6 weeks
# Store Number 1107 will sell R$260,716.01 in the next 6 weeks
# Store Number 1109 will sell R$202,209.83 in the next 6 weeks
# Store Number 1111 will sell R$209,470.26 in the next 6 weeks
# Store Number 1112 will sell R$392,826.79 in the next 6 weeks
# Store Number 1113 will sell R$266,002.11 in the next 6 weeks
# Store Number 1114 will sell R$749,676.47 in the next 6 weeks
# Store Number 1115 will sell R$288,358.42 in the next 6 weeks
